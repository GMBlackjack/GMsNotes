# %% [markdown]
# # Titan Papers
#
# ## The Big One
#
# ### This is going to demand I subdivide isn't it?

# %% [markdown]
# ## General Properties
#
# **Smith, 1980**: The Radius of Titan From Pioneer Saturn Data
#
# https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1029/JA085iA11p05943
#
# Ever wanted to know how to calculate the radius of an object? Well, here you are. Do note that the radius is wrong as at this point we did not know the extent of the atmosphere. It did sucessfully predict the blue "halo" Voyager saw later.
#
# **Lopes et al, 2019**: Titan as Revealed by the Cassini Radar
#
# https://link.springer.com/article/10.1007/s11214-019-0598-6
#
# This is just a really really really big summary of "all the things the Cassini Radar found on Titan." This includes: interior information, global shape information, compositional information, subsurface information, surface geology, temporal change, surface/atmosphere interaction, etc. Yes I just named the headings this thing is big. Probably a ton in here, but I like how obviously freaky Xanadu is in some of the maps.
#
# **Lebreton et al, 2009**: Results from the Huygens Probe on Titan
#
# https://link.springer.com/article/10.1007/s00159-009-0021-5
#
# Similar to the above, but for Huygens itself. Contains atmospheric strucutre/properties, aerosols/clouds, surface, some speculation on origins of the atmosphere and Titan, etc. Your one-stop-shop for Huygens stuff.

# %% [markdown]
# ## Atmosphere
#
# **Kuiper, 1944**: Titan: a Satellite With an Atmosphere
#
# https://articles.adsabs.harvard.edu/pdf/1944ApJ...100..378K
#
# The confirmed discovery of Titan's atmosphere using spectroscopy that found methane signatures. Good for historic reference. Also good if you need to cite that Titan is orange, for some reason.
#
# **M. Es-sayeh et al, 2023**: Updated Radiative Transfer Model for Titan in the Near-infrared Wavelength Range: Validation against Huygens Atmospheric and Surface Measurements and Application to the Cassini/VIMS Observations of the Dragonfly Landing Area.
#
# https://iopscience.iop.org/article/10.3847/PSJ/acbd37/meta
#
# This paper is primarily concerned with the description of an updated radiative transfer model for Titan's atmosphere, including new data and some better procedures. It compares the results of its previous model with the new model for the Huygens Landing Site. Of special note is the discovery of the non-integer Fractal Dimension of the aerosols; previous work had used 2, but this work finds that results work best with 2.3 or 2.4 Fractal Dimension. (Quick explanation: fractal dimension is how much an object's "measure" scales with doubling. Squares when doubled go like $x^2$, with a fractal dimension of 2, while cubes go like $x^3$, thus 3. The aerosol surface area is thus structured enough, or "rough" enough, to scale faster than a simple 2D model would imply). There is a lot of discussion on how to remove seams in VIMS images due to viewing geometry differences, and the model is also applied to Selk Crater and surrounding areas, including the Dragonfly Landing Site. This paper is a bit too crammed full of stuff, in my opinion, and could have been split up. Regardless, the ultimate goal of the model was to extract surface albedo and assign labels to different terrain types, which it appears to have succeeded at.
#
# **Barnes et al, 2018**: Titan's Twilight and Sunset Solar Illumination
#
# https://iopscience.iop.org/article/10.3847/1538-3881/aae519/meta
#
# A great example paper of using SRTC++ in an actual application, especially one that's not the most obvious--using sections of Titan's surface as the detectors. It generates what Titan susnets would look at from different wavelengths, including visible. (Wait, weren't we not very good otuside of the IR windows? Check with Dr. Barnes about this). Also just nice pictures.
#
# **Barnes et al, 2020**: Diffraction-limited Titan Surface Imaging from Orbit Using Near-infrared Atmospheric Windows
#
# https://iopscience.iop.org/article/10.3847/PSJ/ab91b6/meta
#
# Compares a SRTC++ code with an analytic code for how high of a resolution could we expect to get from a Titan orbiter. Turns out, answer is about 20 meter pixels. Shows that SRTC++ has some improvements over the analytical version largely due to the inclusion of the forward-scattering function. Also splits up components of what is detected from direct-from-surface to atmospheric to surface-then-atmospheric-scattering. The differneces are striking at different wavelengths.
#
# **Negrao et al, 2005**: On the Latitudinal Distribution of Titan's Haze at the Voyager Epoch
#
# https://www.sciencedirect.com/science/article/pii/S0032063304002545
#
# Shows how Voyager's data pointed out the variation in Titan's haze from the polar regions to the equatorial. Talks a lot about modeling it all. Honestly not entirely sure this one's worth saving here, but here we are anyway.
#
# **Brown et al, 2002**: Direct Detection of Variable Tropospheric Clouds Near Titan's South Pole
#
# https://www.nature.com/articles/nature01302
#
# So this paper has a few interesitng things. First, direct images of Titan clouds, a first. Second, recognition that the clouds congregate near poles. Third, a hilariously wrong thought is mentioned--that the clouds should be congregating near the equator, perhaps eternally! No, this ain't right. The paper does go to discuss that the previous theories may be wrong, but I do find it amusing. Oh, fourth, a nice example of adaptic optics power.

# %% [markdown]
# ## Surface (in general)
#
# ### y'know, not specifically lake stuff
#
# **Lopes et al, 2020**: A Global Geomorphologic Map of Saturn's Moon Titan
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7271969/
#
# This is the paper with all the terrain maps splitting Titan up into six types of areas: lakes, craters, dunes, hummocky stuff, labyrinths, and plains. Notably craters are questionable as a "terrain type" and only some of the lakes are actually filled with liquid. Good place to refer to basic descriptions of each of these. Excellent map to boot, though not very high resolution, and can be questionable in interpretaion. A good general place to go.
#
# **Malaska et al, 2016**: Geomorphological Map of the Afekan Crater Region, Titan: Terrain Relationships in the Equatorial and Mid-latitude Regions.
#
# https://www.sciencedirect.com/science/article/pii/S0019103516000889
#
# This is a paper concerned with a single crater but that's not why we use it. Sure, Afekan Crater, you're very interesting, but this paper's main use is the fact that it heavily subdivides the major terrain types of Titan into many different types, each with their own unique section that describes them. Contains labyrinths, but not lakes. there aren't lakes near Afekan Crater. This is a more fine-tuned look at topography compared with the above paper.
#
# **Solomonidou et al, 2018**: The Spectral Nature of Titan's Major Geomorphological Units: Constraints on Surface Composition.
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JE005477
#
# An alternative look at the types of terrain on Titan, though this one does not attempt to make a map, rather it attempts to characterize and identify the various spectral properties of the topographic units. This allows some tentative material identification, though I mean tentative. We can be pretty sure there is water ice in some of the locations, particuarly at higher latitudes. Beyond that we raelly aren't sure, the equator has organics, but what even are those organics? The paper puts up a few theories as to why this disparity in composition with latitude exists.
#
# **Lopes et al, 2016**: Nature, Distribution, and Origin of Titan's Undifferentiated Plains
#
# https://www.sciencedirect.com/science/article/pii/S0019103515005576
#
# Discussion of the Blandlands. The empty boring planes. You'd think it would be the simple kind of terrain but NO it's VERY CONFUSING and has all SORTS of issues. The conclusion in this paper is that the plains are sedimentary in origin and primarily driven by wind processes, but there are other possible contributing factors. It also relates the plains to other types of topography, such as the dunes and labyrinths.
#
# **Malaska et al, 2020**: Labyrinth Terrain on Titan
#
# https://www.sciencedirect.com/science/article/pii/S0019103520301524
#
# Paper that discusses the Labyrinths. Goes into detail, subdivides the labyrinth, draws attention to the unusual Kronin Labyrinthus region. Radar-focused paper with lots of good images and explanations, as well as a global (at the time) mark of all known labyrinths. Goes into a truly stupendous amount of detail, surely it's useful somehow, right? So much labyrinth information.
#
# **Lorenz et al, 1995**: Prediction of Aeolian Features on Planets: Application to Titan Paleoclimatology
#
# https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1029/95JE02708
#
# This paper is only important because the conclusion it draws, "dunes on Titan are unlikely," is completely wrong and disproven by the next paper on this list. By the same researcher.
#
# **Lorenz et al, 2006**: The Sand Seas of Titan: Cassini RADAR Observations of Longitudinal Dunes
#
# https://www.science.org/doi/10.1126/science.1123257
#
# Discovery paper for the Dunes! Discovered via Cassini Radar. Talks about how to identify dunes from radar images. Naturally there are better papers to characterize the dunes, this is just the discovery one.
#
# **Malaska et al, 2016**: Material Tarnsport Map of Titan: The Fate of Dunes.
#
# https://www.sciencedirect.com/science/article/pii/S0019103515004431?ref=pdf_download&fr=RR-2&rr=81be2fedaab330a0
#
# Here's a fun one. Where is all the sand going? Well we don't know where it's coming from and we don't know where it ends. But we do know where it's currently going thanks to this paper and a nice map with a ton of arrows! The flow is west to east. (Or left to right. Read maps carefully just because a longitude is labeled E doesn't mean it's pointing east, unfortunately... directions are fun). This paper concludes a few things. One, that topography is not the primary dictator of dune flow direction, at least not at global scale--rather the mechanism is likely wind/air based. The arrows imply that the dunes don't actually sink at the equator, but move outward toward the 35 degree latitude lines, the central "belt" is an unstable equilibrium. Yes, there are few if any dunes up there at 35 degrees, hence the fun. The answer isn't really clear as to why this is, but the paper suggests the dominant theory is that the dune material is up there it's just changed form. Secondary theory: the dunes are young and have not yet finished their migration to the sink.
#
# **Lucas et al, 2014**: Growth Mechanisms and Dune Orientation on Titan
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2014GL060971
#
# So this isn't in this paper but I think we need context: winds on earth go east to west. The dune transport on Titan goes west to east. This is backward, Titan's not spinning retrograde or anything. So... what do? This paper suggests a mechanism for this problem that isn't really stated in the abstract. (Did they even know it was a problem or did they assume it was obvious?) Anyway the solution is that the sand is transported by storms or occasionally fast gusts. Examining the implicaitons, this means that Titan winds would in fact go east to west normally, until upsets occur. (Note: this is highly speculative and doesn't seem to be definite; compare with Huygens?) Also the terms "eastward" "westward" "easterly" and "westerly" are all used in this paper which is infurating. WestWARD is going TO the west. WesterLY is coming FROM the west.
#
# **Bonnefoy et al, 2015**: Compositional and Spatial Variations in Titan Dune and Interdune Regions from Cassini VIMS and RADAR.
#
# https://www.sciencedirect.com/science/article/pii/S0019103515004194
#
# This paper is longer than it needs to be, of that I am sure. However it does have good information about the areas on Titan that are *between* dunes, noting that these "interdunes" differ based on where the dunes are. It also discusses an automated dune mapping algorithm which... is cool but I'm not sure it helps me in particular here. Also notable for combining both radar and VIMS data. There does appear to be an unusual interdune area that doesn't match the rest that is linked to Caladan Planitia but this isn't explained very well. At least I didn't understand it when I reviewed the paper anyway. Could be a me problem.
#
# **Radebaugh et al, 2007**: Mountains on Titan Observed by Cassini Radar
#
# https://www.sciencedirect.com/science/article/pii/S0019103507002771
#
# This is the mountains paper. It talks about the mountains and possible formation mechanisms. We will note that it calls them "young" in the abstract when later results are pretty sure they are the oldest terrains--though it appears to focus more on the fact that Titan's surface itself is relatively young. Which. Yeah that checks out.
#
# **Radebaugh et al, 2011**: Regional Geomorphology and History of Titan's Xanadu Province
#
# https://www.sciencedirect.com/science/article/pii/S0019103510002940
#
# It's Xanadu time, baby! This is a paper that describes Xanadu from the radar perspective, and includes the Regios as part of Xanadu. It examines the divisions and different areas within Xanadu. We have the Drainages, the Rugged Terrains, the Belts, and the Regios of course. (Though the Regios are contained within the "Flow Complexes" region). It identifies water in Xanadu but notes the structure is likely not pure ice--the theory is that we have icy bedrock covered by some stuff. We also address directly the freaky problem of Xanadu being *lower in elevation than neighboring areas.* You know. *Which is mostly dunes*. Xanadu is not filled with sand. Much confusion. The paper proposes a Xanadu formation theory which involves the crust bunching up in ancient times and then sinking later coupled with erosion. Details within, obviously. Another paper about how unique Xanadu is.
#
# **Lnaghans et al, 2013**: Titan's Xanadu Region: Geomorphology and Formation Scenario
#
# https://www.sciencedirect.com/science/article/pii/S0019103513000316
#
# Oh boy another paper about how weird Xanadu is! This paper is also an example of "hey um what about we examine all those formation theories?" including the theories of the above paper. This paper also includes the Regios and goes into a bit more detail about the different Xanadu features, and brings up the idea that the Regios are cryovolcanic. (Not evaporites, which is the other contender). It shoots down the "crater basin" theory rather quickly. Other theories, methane outgassing and thermal evolution, are "consistent" theories but no definite answer was determined. Funnily enough the paper largely agrees with the above one, though this one is definitely less certain about its conclusions. Paper also points out that Xanadu might not be a single unified palce but rather divided.
#
# **Neish et al, 2015**: Spectral Properties of Titan's Impact Craters Imply Chemical Weathering of its Surface
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5012121/
#
# You ever just want to look at craters on Titan in general? This is the paper for you! In addition to examining craters individually, the total crater population shows a "timeline" of crater erosion that slowly reveals more water ice. This paper rather nicely uses both radar and VIMS data. Curious note: fresh craters show no water ice, despite supposedly unearthing deep into Titan's crust, the mechanism for ice-organics mixing is unknown, but this paper theorizes a few options. (porous ice bedrock or "hydrothermal alteration" of rock after impact.) Chemical weathering is clear.
#
# **Crosta et al, 2021**: Modeling the Formation of Menrva Impact Crater on Titan: Implications for Habitability
#
# https://www.sciencedirect.com/science/article/pii/S0019103521003365
#
# Titan doesn't have many craters. But it does have one truly ginormous one, Menrva crater. This paper is a formation model of Menrva with a specific focus on it potentially allowing for biotic processes, maybe even cracking the crust and reaching the subsurface ocean. It's hard to transport material from the subsurface ocean to the surface, but this is certainly one way to do it. This paper contains topographic information, ISS data, VIMS data, radar data, a simulation of formation, and theorization. The ironic result is that, in contrast to giant impacts on Earth, Menrva crater actually greatly improves the environment on Titan for life. The breach/melt of the ice crust happens in most simulations. Another funny result: even though the impact is so huge and the crater obvious, the topography is still very level, so much so that the simulation doesn't really show the final crater on the final state, even though we know it's there. Minimal topography everyone! (Personal note: life improvement happens even if the inner ocean isn't reached at the impact just creates a water lake, which it most certainly did).
#
# **Soderblom et al, 2010**: Geology of the Selk Crater Region on Titan from Cassini VIMS Observations
#
# https://www.sciencedirect.com/science/article/pii/S0019103510001028
#
# Selk Crater is interesting and worthy of being looked at. That's what this paper does, largely topographically, examining both the crater itself and the Bench. This crater is notably extra important since it's the one Dragonfly is visiting but this paper isn't concerned with that. We don't really know what the Bench is but two theories are discussed: fluidized ejecta flow or a streamlined upland flow due to erosion. Notably the Bench looks to potentially be made *overtop* an ancient crater highland. Lots of mysteries afoot.
#
# **Lorenz et al, 2021**: Selection and Charateristics of the Dragonly Landing Site Near Selk Crater, Titan
#
# https://iopscience.iop.org/article/10.3847/PSJ/abd08f/meta
#
# Selk Crater looked at from the point of view of the Dragonfly mission. Talks about why it was chosen and what we hope to find there, as well as terrestrial analogs.
#
# **Mouelic et al, 2008**: Mapping and Interpretation of Sinlap Crater on Titan Using Cassini VIMS and RADAR Data
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2007JE002965
#
# Sinlap Crater is, to me, useful when compared to Selk, as they both have extensions. Selk has the Bench, and Sinlap has the "weird blue thing" that doesn't really have a nice name. (dark bluish parabolic area doesn't really cut it, honestly). The thing is, the Bench is similar to Selk crater. Sinlap crater's "blue thing" is, well, decidedly NOT similar to Sinlap. It lights up like a christmas tree in VIMS but is kind of invisible in radar, possibly enriched in water ice? Likely a different penetration depth situation. The proposed theory is that this is a vapor plume created from the crater itself while wind was blowing. Paper also details little fun things about Sinlap but the main mystery is the blue thing.
#
# **Zarnecki et al, 2005**: A Soft Solid Surface on Titan as Revealed by the Huygens Surface Science Package
#
# https://www.nature.com/articles/nature04211
#
# Huygens talks about landing and what the surface is like. It's amazing both how much and how little we know from this landing. No composition, very uncertain words on consistency, but we've got a picture and a lot of hsape data. But is it like clay or snow or sand!?
#
# **Soderblom et al, 2007**: Topography and Geomorphology of the Huygens Landing Site on Titan
#
# https://www.sciencedirect.com/science/article/pii/S0032063307001298
#
# Geomorphology of the Huygens Landing Site and surrounding regions. Good for some careful examinations of close-up terrain shape, indicating fluvial and tectonic activity was likely required to form the region; including evidence of flooding at some point. Also we have pictures of the dunes from very very very far away, kind of blurry.

# %% [markdown]
# ## Lakes
#
# ### And Lake-Related Stuff
#
# **Stofan et al, 2007**: The Lakes of Titan
#
# https://www.nature.com/articles/nature05438
#
# This paper is very simple but very important. It's the DISCOVERY of the lakes on Titan. Woot! Uses radar images.
#
# **Hayes, 2016**: The Lakes and Seas of Titan
#
# https://www.annualreviews.org/doi/pdf/10.1146/annurev-earth-060115-012247
#
# An excellent summary of research concerning the lakes and seas of Titan. As a review it probably shouldn't be cited itself, but it can point to other citations, and goes into enough detail to showcase what facts about the seas we know and which ones are particuarly relevant / the subject of current study.
#
# **Hayes et al, 2017**: Topographic Constraints on the Evolution and Connectivity of Titan's Lacustrine Basins
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017GL075468
#
# The important results in this paper are 1) that the big seas have the same "sea level" and are likely connected; 2) isolated lakes are found at many different "sea levels" and are unconnected. There's more here about formation but that's why it is important.
#
# **Grima et al, 2017**: Surface Roughness of Titan's Hydrocarbon Seas
#
# https://www.sciencedirect.com/science/article/pii/S0012821X17303163
#
# How rough are the seas? From the data in this paper, not very rough at all. Very smooth. There is SOME texture though, so it's not physically freaky, just... calm. This research uses radar to examine roughness of the three seas. Punga is rougher than the other two seas but still not very intense. Notably this only examines large-scale roughness, small-scale could obviously be different for localized things, it also wouldn't catch transient wave activity.
#
# **Mastrogiuseppe et al, 2014**: The Bathymetry of a Titan Sea
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2013GL058618
#
# This is the Ligea Mare paper. Focuses mostly on depth (bathymetry).
#
# **Lorenz et al, 2014**: A Radar Map of Titan Seas: Tidal Dissipation and Ocean Mixing Through the Throat of Kraken
#
# https://www.sciencedirect.com/science/article/pii/S0019103514001973
#
# Gonna be honest. Primarily use this paper just to confirm the existence of the Throat of Kraken. Guess it also has a good radar map and bathymetry of Kraken Mare. ...Actually this is probably just a good "Kraken Mare" Paper. (Makes a nice observation comparing the Throat to Earth's Straight of Gibraltar)
#
# ...What do you mean we need a Punga Mare paper, I don't think so.
#
# **Dhingra et al, 2018**: Large Catchment Area Recharges Titan's Ontario Lacus
#
# https://www.sciencedirect.com/science/article/pii/S0019103516308028
#
# Did someone say "obligatory Ontario Lacus" paper? Because I just did! Also discusses why Ontario is still filled while the other basins are empty, pointing out that it might just be because this particular basin has a large "catchment area". AKA it grabs the most water and funnels it to Ontario. Just come here for Ontario information.
#
# **Barnes et al, 2009**: Shoreline Features of Titan's Ontario Lacus from Cassini/VIMS Observations
#
# https://www.sciencedirect.com/science/article/pii/S0019103508004582
#
# So. Um. Ontario Lacus is a bit odd for more reasons than just being the only south polar "sea" or "major lake" or whatever. See, it also has shoreline "bathtub rings." This paper mainly goes on about how we can clearly see this stuff but haven't the foggiest idea what it is. Evaporite? Shelf? Beach? Floating stuff? *shrug.* There's also two distinct areas in the rings which is just even weirder.
#
# **Poggiali et al, 2016**: Liquid-filled Canyons on Titan
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2016GL069679
#
# The "river." More accurately just a canyon that is currently filled because the local sea level has risen (theoreitcally), "flow" here isn't really river-like. Vid Flumina is probably better described as a "liquid-floored canyon" than a river. It is huge though and obviously canyons *form* due to fluvial processes, so we've got some curiosities here.
#
# **Vixie et al, 2015**: Possible Temperate Lakes on Titan.
#
# https://www.sciencedirect.com/science/article/pii/S0019103515002110
#
# The only confirmed lakes of Titan are on the poles, but here we have evidence of *possible* lakes in mid-latitude regions. The actual identity is still shrouded in mystery, and this paper is part of the reason we need better radiative transfer models so we can determine if these are really lakes or not. Has locations of many potential candidates, and includes a discusison on Griffith et all 2012's equatorial candidate. This paper can't rule it out entirely but it does not think the equatorial candidate has the right properties.
#
# **Griffith et al, 2012**: Possible Tropical Lakes on Titan From Observations of Dark Terrain.
#
# https://www.nature.com/articles/nature11165
#
# A mysterious dark spot on Titan that might be an equatorial lake. However, other papers I read cast doubt on this claim, but it is a possible candidate for later research once we have a radiative transfer model running.
#
# **Barnes et al, 2011**: Organic Sedimentary Deposits in Titan's Dry Lakebeds: Probable Evaporite
#
# https://www.sciencedirect.com/science/article/pii/S0019103511003393
#
# Probable evaporite locations. Helpful for comparing to probable evaporite locaitons. Also adresses the presence of "granular lakes" which are transitional between filled and empty, correlated to partially filled areas or just mudflats. This paper brags a little bit at how VIMS can identify more details about surface liquid than radar. There is a strong correlation between these lakebeds and the Regios. Mentions the Tue Regio absorption line. Paper concludes that these dry lakebeds are almost certainly evaporite, big discovery if confirmed. Limitation: no clue what it's made out of. As usual.
#
# **Birch et al, 2018**: Morphological Evidence that Titan's Southern Hemisphere Basins are Paleoseas
#
# https://www.sciencedirect.com/science/article/pii/S0019103517306097
#
# Paleoseas (ancient seas that are no longer seas anymore) are still of importance for research. So let's dig in! Basically it identifies four large areas at the south pole that were likely filled with liquid in the deep past. (Admittedly it relies on the "Saturn Orbit Configuraiton" explanation to justify this making sense, which is  controversial). Only problem is that there is little to no evaporite in the four basins, though this may just be because the basins are so old the evaporite has been "cleaned away" though some mechanism or other. Yes one of the basins contains Ontario. The curious observaiton made is that these paleoseas have no sign of evaporite, but the Regios (equatorial and not really discussed here) DO and would have to be wetted more recently. Fascinating.

# %% [markdown]
# ## Interior
#
# ### This is gonna have the fewest papers
#
# **Lopes et al, 2013**: Cryovolcanism on Titan: New Results from Cassini RADAR and VIMS
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/jgre.20062
#
# Even though this paper is looking at surface images it is concerned largely with cryovolcanism evidence, an inteiror process. It examines a few locations but the one we care about is the freakish Doom Mons and the hole Sotra Patera that are right next to each other, highly suggestive of cryovolcanism "kablooey".

# %% [markdown]
# ## History
#
# **Lorenz and Mitton, 2002**: Lifting Titan's Veil: Exploring the Giant Moon of Saturn
#
# https://web.archive.org/web/20050222073209/https://assets.cambridge.org/052179/3483/sample/0521793483ws.pdf
#
# Excellent source of basic history of Titan's discovery and various advances up until before the Cassini mission. This is just the first chapter of a larger book and yet I have not read the larger book--this gives an excellent overview though, sufficient to understand the path Titan has taken through history.
