# %% [markdown]
# # Demonstration: Global Albedo Retrival Maps

# %%
inputs = [7,1] #Index 0: wavs, 0-7. Index 1: 0, normal; 1, <40 emis; 2, MAD; 3, capped MAD
#shallow (emis <= 40) toggle 0 false, 1 true.
from IPython.display import IFrame, display
wavs = ["0.93um","1.08um","1.27um","1.59um","2.01um","2.69um","2.79um","5.00um"]
shallow = ["AlbedosShallow", "AlbedosShallowR", "MAD", "MADSc"]
if inputs[1] == 0: print("All observation angles present, 25 km resolution or better. " + wavs[inputs[0]])
if inputs[1] == 1: print("Emission under 40 degrees, 25 km resolution or better. " +  wavs[inputs[0]])
display(IFrame("TitanGlobal"+shallow[inputs[1]]+wavs[inputs[0]]+".pdf",width="100%", height=800))
# Out:
# Emission under 40 degrees, 25 km resolution or better. 5.00um
#         <iframe
#             width="100%"
#             height="800"
#             src="TitanGlobalAlbedosShallowR5.00um.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Full Data Capacity:
#
# ## For every lat, lon, each of the following lists exists:
#
# ### I/F (0.93um, 1.08um, 1.27um, 1.59um, 2.01um, 2.69um, 2.79um, 5.00um)
#
# ### Retrieved Albedo (0.93um, 1.08um, 1.27um, 1.59um, 2.01um, 2.69um, 2.79um, 5.00um)
#
# ### Observation Angle (incidence, emission, azimuth)
#
# ### Cube Name
#
# ## All lists are the same size, and can be crossreferenced to filter out certain observations.
