# %%
import site
print(site.getsitepackages())
# Out:
# ['\\\\?\\C:\\Users\\deran\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server', '\\\\?\\C:\\Users\\deran\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages']

# %%
import IPython
import os

ipython_dir = IPython.paths.get_ipython_dir()
startup_dir = os.path.join(ipython_dir, 'profile_default', 'startup')

print(f"The IPython configuration directory this kernel is using is:")
print(f"    {ipython_dir}")
print(f"\nThe correct startup directory is:")
print(f"    {startup_dir}")
# Out:
# The IPython configuration directory this kernel is using is:
#     C:\Users\deran\.ipython
#
# The correct startup directory is:
#     C:\Users\deran\.ipython\profile_default\startup

# %%
import os

mpl_backend_var = os.environ.get('MPLBACKEND')

print(f"The value of the MPLBACKEND environment variable is: {mpl_backend_var}")
# Out:
# The value of the MPLBACKEND environment variable is: module://matplotlib_inline.backend_inline

# %%
# !echo "--- Checking Kernel Spec Path ---"
# !jupyter kernelspec list
# !echo "--- Displaying Contents of the Apparent kernel.json ---"
# !type "C:\Users\deran\AppData\Roaming\jupyterlab-desktop\jlab_server\share\jupyter\kernels\python3"
# Out:
# "--- Checking Kernel Spec Path ---"
# Available kernels:
#   python3    C:\Users\deran\AppData\Roaming\jupyterlab-desktop\jlab_server\share\jupyter\kernels\python3
# "--- Displaying Contents of the Apparent kernel.json ---"
# Access is denied.
