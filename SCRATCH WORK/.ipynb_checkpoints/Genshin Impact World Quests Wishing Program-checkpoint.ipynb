# %% [markdown]
# # Genshin Impact World Quests Wishing Program
#
# Since it would be VERY annoying to update the wishing tables every time a new artifact set or weapon comes out, instead I'm just going to program a general auto-wisher. Also this will be faster even if we have a table set up.
#
# Anyway this program only takes in one input: a number 1-5 that is the "smallest artifact/weapon you have equipped." You can't enter 0 even if you have empty equipment slots. Once this number is altered in the code, just run it and it should spit out the result. If you have jupyter notebook you can run it directly in this file, but it is pure python so you can also just run it however you want.
#
# Note that this code will sometimes spit out weapons that aren't in the Treasure Vault. If you get one of those run to me (GM) and I'll take it as a sign that it's time to add that weapon.

# %%
# This is the only number you set, 1-5, based on the rarity of the lowest item you have equipped.
# You can't put in zero. Well, you can, but the program sets it to 1 manually if you do.
input = 2
# The rest of this is not for you to mess with. But you can look if you're curiuos. 

# PART 1: Making a lot of lists
# The first thing this code does is just generate a ton of lists.
weaponTypes = ["Sword", "Claymore", "Polearm", "Catalyst", "Bow"]
artifactTypes = ["Flower", "Feather", "Timepiece", "Goblet", "Circlet"]
timepieceStats = ["HP", "ATK", "EM", "Armor"]
circletStats = ["HP", "ATK", "EM", "Armor", "Healing Bonus", "Crit Target Reduction"]
gobletStats = ["HP", "ATK", "EM", "Armor", "Damage Bonus"]
damageStats = ["Anemo", "Geo", "Electro", "Dendro", "Hydro", "Pyro", "Cryo", "Physical"]

artifactSets = [
    "Adventurer (ADV)", "Lucky Dog (LUD)", "Traveling Doctor (TDR)", "Resolution of Sojourner (RDS)",
    "Tiny Miracle (TMC)", "Berserker (BZK)", "Instructor (INS)", "The Exile (EXI)", "Defender's Will (DFW)",
    "Brave Heart (BVH)", "Martial Artist (MAA)", "Gambler (GAM)", "Scholar (SCH)", "Gladiator's Finale (GLF)",
    "Wanderer's Troupe (WNT)", "Bloodstained Chivalry (BSC)", "Maiden Beloved (MAB)", "Noblesse Oblige (NOO)",
    "Viridescent Venerer (VIV)", "Archaic Petra (ARP)", "Retracing Bolide (REB)", "Thundersoother (THS)",
    "Thundering Fury (THF)", "Lavawalker (LVW)", "Crimson Witch of Flames (CWF)", "Blizzard Strayer (BZS)",
    "Heart of Depth (HOD)", "Tenacity of the Milileth (TOM)", "Pale Flame (PAF)", "Shimenawa's Reminiscence (SHR)",
    "Emblem of Severed Fate (ESF)", "Husk of Opulet Dreams (HPD)", "Ocean-Hued Clam (OHC)", 
    "Vermillion Hereafter (VHA)", "Echoes of an Offering (EOO)", "Deepwood Memories (DWM)", 
    "Gilded Dreams (GLD)", "Desert Pavillion Chronicle (DPC)", "Flower of Paradise Lost (FPL)", 
    "Nymph's Dream (NYD)", "Vourukasha's Glow (VKG)", "Marechausse Hunter (MCH)", "Golden Troupe (GTR)",
    "Song of Days Past (SDP)", "Nighttime Whispers in the Echoing Woods (NWW)"
]

threeStarSwords = ["Cool Steel", "Dark Iron Sword", "Filet Blade", "Harbinger of Dawn", "Skyrider Sword", 
                   "Traveler's Handy Sword"]
fourStarSwords = [
    "Amenoma Kageuchi", "Blackcliff Longsword", "Cinnabar Spindle", "Favonius Sword", "Festering Desire", 
    "Finale of the Deep", "Fleuve Cendre Ferryman", "Iron Sting", "Kagotsurube Isshin", "Lion's Roar",
    "Prototype Rancour", "Royal Longsword", "Sacrificial Sword", "Sapwood Blade", "Sword of Descension", 
    "Sword of Narzissenkreuz", "The Alley Flash", "The Black Sword", "The Dockhand's Assistant", "The Flute",
    "Toukabou Shigure", "Wolf-Fang", "Xiphos' Moonlight"
]
fiveStarSwords = [
    "Aquila Favonia", "Freedom-Sworn", "Haran Geppaku Futsu", "Key of Khaj-Nisut", "Light of Foliar Incision",
    "Mistsplitter Reforged", "Primordial Jade Cutter", "Skyward Blade", "Spelndor of Tranquil Waters",
    "Summit Shaper"
]

threeStarClaymores = [ "Bloodstained Greatsword", "Debate Club", "Ferrous Shadow", "Skyrider Greatsword", 
                      "White Iron Greatsword"]
fourStarClaymores = [
    "Akuoumaru", "Blackcliff Slasher", "Favonius Greatsword", "Forest Regalia", "Katsuragikiri Nagamasa",
    "Lithic Blade", "Luxurious Sea-Lord", "Mailed Flower", "Makhaira Aquamarine", "Portable Power Saw",
    "Prototype Archaic", "Rainslasher", "Royal Greatsword", "Sacrificial Greatsword", "Serpent Spine",
    "Snow-Tombed Starsilver", "Talking Stick", "The Bell", "Tidal Shadow", "Ultimate Overlord's Mega Magic Sword", "Whiteblind"
]
fiveStarClaymores = [
    "Beacon of the Reed Sea", "Redhorn Stonethresher", "Skyward Pride", "Song of Broken Pines", 
    "The Unforged", "Verdict", "Wolf's Gravestone"
]

threeStarPolearms = ["Black Tassel", "White Tassel", "Halberd"]
fourStarPolearms = [
    "The Catch", "Ballad of the Fjords", "Blackcliff Pole", "Crescent Pike", "Deathmatch", "Dragon's Bane",
    "Dragonspine Spear", "Favonius Lance", "Kitain Cross Spear", "Lithic Spear", "Missive Windspear",
    "Moonpiercer", "Prospertor's Drill", "Prototype Starglitter", "Rightful Reward", "Royal Spear", 
    "Wavebreaker's Fin"
]
fiveStarPolearms = [
    "Calamity Queller", "Engulfing Lightning", "Primordial Jade Winged-Spear", "Skyward Spine",
    "Staff of Homa", "Staff of the Scarlet Sands", "Vortex Vanquisher"
]

threeStarCatalysts = [ "Emerald Orb", "Magic Guide", "Otherworldly Story", "Thrilling Tales of Dragon Slayers",
                      "Twin Nephrite"]
fourStarCatalysts = [
    "Ballad of the Boundless Blue", "Blackcliff Agate", "Dodoco Tales", "Eye of Perception", "Favonius Codex",
    "Flowering Purity", "Frostbearer", "Fruit of Fulfillment", "Hakushin Ring", "Mappa Mare", "Oathsworn Eye",
    "Prototype Amber", "Royal Grimoire", "Sacrificial Fragments", "Sacrificial Jade", "Solar Pearl", "The Widsith",
    "Wandering Evenstar", "Wine and Song"
]
fiveStarCatalysts = [
    "A Thousand Floating Dreams", "Cashflow Supervision", "Everlasting Moonglow", "Jadefall's Splendor", 
    "Kagura's Verity", "Lost Prayer to the Sacred Winds", "Memory of Dust", "Skyward Atlas", 
    "Tome of the Eternal Flow", "Taluytullah's Remembrance"
]

threeStarBows = [ "Messenger", "Raven Bow", "Recurve Bow", "Sharpshooter's Oath", "Slingshot"]
fourStarBows = [
    "Alley Hunter", "Blackcliff Warbow", "Compound Bow", "End of the Line", "Fading Twilight",
    "Favonius Warbow", "Hamayumi", "Ibis Piercer", "King's Squire", "Mitternachts Waltz", "Mouun's Moon",
    "Predator", "Prototype Crescent", "Range Gauge", "Royal Bow", "Rust", "Sacrificial Bow", 
    "Scion of the Blazing Sun", "Song of Stillness", "The Stringless", "The Viridescent Hunt", 
    "Windblume Ode"
]
fiveStarBows = [
    "Amos' Bow", "Aqua Simulacra", "Elegy for the End", "Hunter's Path", "Polar Star", "Skyward Harp",
    "The First Great Magic", "Thundering Pulse"
]

# Now that we have set all that NONSENSE, we can now get to the actual code which decides things.
import random # we use this to make random numbers.

# First, use the initial roll to determine what we get.
initialRoll = random.randint(1,20) # rolls a number from 1 to 20.
rarity = 0 # a variable for holding our rarity value. 
isWeapon = -1 # will be set to 1 if we have weapon, 0 if it's an artifact. -1 is Stella Fortuna. 

if (input < 1):
    input = 1
    # Just in case someone entered it incorrectly. 
    # Large inputs are handled automatically due to how the code runs.

#Big if statement to determine what we rolled.
if (initialRoll == 20):
    print("Stella Fortuna (Constellation)")
    # This is the easy case, where the roll immediately translates into what we want. 
elif (initialRoll == 19):
    isWeapon = 1
    rarity = input+2
elif (initialRoll == 18):
    isWeapon = 0
    rarity = input+2
elif (initialRoll < 18 and initialRoll > 14):
    isWeapon = 1
    rarity = input+1
elif (initialRoll < 15 and initialRoll > 10):
    isWeapon = 0
    rarity = input+1
elif (initialRoll < 11 and initialRoll > 5):
    isWeapon = 1
    rarity = input
else:
    isWeapon = 0
    rarity = input

if (rarity > 5):
    rarity = 5
# Believe it or not now we know all we need to about the initial roll. 

if (isWeapon == 0):
    print(str(rarity) + "-Star Artifact")
    print(random.choice(artifactSets))
    artifactType = random.choice(artifactTypes)
    print(artifactType)
    # Based on the artifact type, you might get different stats.
    if (artifactType == "Flower"):
        print("+" + str(rarity*3) + " HP")
    elif (artifactType == "Feather"):
        print("+" + str(rarity) + " ATK")
    elif (artifactType == "Timepiece"):
        chosenStat = random.choice(timepieceStats)
        if(chosenStat == "HP"):
            print("+" + str(rarity*3) + " HP")
        else:
            print("+" + str(rarity) + " " + chosenStat)
    elif (artifactType == "Goblet"):
        chosenStat = random.choice(gobletStats)
        if(chosenStat == "HP"):
            print("+" + str(rarity*3) + " HP")
        elif(chosenStat == "Damage Bonus"):
            print("+" + str(rarity*2) + " " + random.choice(damageStats) + " Damage")  
        else:
            print("+" + str(rarity) + " " + chosenStat)        
    elif (artifactType == "Circlet"):
        chosenStat = random.choice(circletStats)
        if(chosenStat == "HP"):
            print("+" + str(rarity*3) + " HP")
        else:
            print("+" + str(rarity) + " " + chosenStat)        
elif (isWeapon == 1):
    print(str(rarity) + "-Star Weapon")
    weaponType = random.choice(weaponTypes)
    print(weaponType)
    if (rarity == 3):
        # Only of weapons of rarity 3 or higher need specific names. 
        if (weaponType == "Sword"):
            print(random.choice(threeStarSwords))
        elif (weaponType == "Claymore"):
            print(random.choice(threeStarClaymores))           
        elif (weaponType == "Polearm"):
            print(random.choice(threeStarPolearms))
        elif (weaponType == "Catalyst"):
            print(random.choice(threeStarCatalysts))  
        elif (weaponType == "Bow"):
            print(random.choice(threeStarBows))
    elif (rarity == 4):
        if (weaponType == "Sword"):
            print(random.choice(fourStarSwords))
        elif (weaponType == "Claymore"):
            print(random.choice(fourStarClaymores))
        elif (weaponType == "Polearm"):
            print(random.choice(fourStarPolearms))
        elif (weaponType == "Catalyst"):
            print(random.choice(fourStarCatalysts))
        elif (weaponType == "Bow"):
            print(random.choice(fourStarBows))     
    elif (rarity == 5):
        if (weaponType == "Sword"):
            print(random.choice(fiveStarSwords))
        elif (weaponType == "Claymore"):
            print(random.choice(fiveStarClaymores))
        elif (weaponType == "Polearm"):
            print(random.choice(fiveStarPolearms))
        elif (weaponType == "Catalyst"):
            print(random.choice(fiveStarCatalysts))
        elif (weaponType == "Bow"):
            print(random.choice(fiveStaBows))
# Out:
# 2-Star Artifact
# Ocean-Hued Clam (OHC)
# Circlet
# +6 HP
