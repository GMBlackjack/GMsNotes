# %% [markdown]
# # Visual Interface Comparator

# %%
# COLLECTED CUBES
tester = r"C:\Users\deran\Desktop\CubeCSVDatabase\T114\CM_1826052615_1.cub.csv" #Good Default Test, global view
ontario = r"C:\Users\deran\Desktop\CubeCSVDatabase\T38\CM_1575506843_1.cub.csv" #Ontario Laucus
specular = r"C:\Users\deran\Desktop\CubeCSVDatabase\T85\CM_1721848119_1.cub.csv" #Specular Point
darkOval = r"C:\Users\deran\Desktop\CubeCSVDatabase\T35\CM_1567239055_1.cub.csv" #the mysterious dark oval
sionascaig = r"C:\Users\deran\Desktop\CubeCSVDatabase\T66\CM_1643411453_1.cub.csv" #temperate lake?
selk = r"C:\Users\deran\Desktop\CubeCSVDatabase\T40\CM_1578263500_1.cub.csv" #Crater!
sedi = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654399736_1.cub.csv" #sediment?
kraken = r"C:\Users\deran\Desktop\CubeCSVDatabase\T104\CM_1787310233_1.cub.csv" #Sea and Specularity!
kraken2 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790066425_1.cub.csv" #Same as above.
kraken3 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T104\CM_1787311929_1.cub.csv" #Same as above.
kraken4 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T104\CM_1787307197_1.cub.csv" #Same as above. Interesting Cube...
#Also the north pole is visible in kraken4. 
#Turns out to not really be Kraken... or even related... oops.
kraken5 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790059135_1.cub.csv" #Same as above.
kraken6 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790059235_1.cub.csv" #Same as above.
kraken7 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T106\CM_1792827131_1.cub.csv" #Same as above. NOT SQUARE! USEFUL!
kraken8 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T110\CM_1805210863_1.cub.csv" #Same as above.
kraken9 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T110\CM_1805212073_1.cub.csv" #Same as above.
krakenA = r"C:\Users\deran\Desktop\CubeCSVDatabase\T110\CM_1805211625_1.cub.csv" #Same as above.

#lower kraken is important to research, so we have some relevant cubes here:
lk1 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T112\CM_1814944467_1.cub.csv"
lk2 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T112\CM_1814944747_1.cub.csv"
lk3 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T109\CM_1802456529_1.cub.csv"
lk4 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T109\CM_1802456559_1.cub.csv"
lk5 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T109\CM_1802456986_1.cub.csv"
lk6 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T106\CM_1792823781_1.cub.csv"
lk7 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790066425_1.cub.csv"
lk8 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790085755_1.cub.csv"
lk9 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T105\CM_1790083283_1.cub.csv"
lkA = r"C:\Users\deran\Desktop\CubeCSVDatabase\T103\CM_1784577732_1.cub.csv"
lkB = r"C:\Users\deran\Desktop\CubeCSVDatabase\T102\CM_1781842039_1.cub.csv"
#GEO AND IMAGE DO NOT MATCH
lkC = r"C:\Users\deran\Desktop\CubeCSVDatabase\T100\CM_1775561747_1.cub.csv" #Can't be used here, file error, use PyVIMS instead
lkD = r"C:\Users\deran\Desktop\CubeCSVDatabase\T82\CM_1708373056_1.cub.csv" #Bad GEO.
lkE = r"C:\Users\deran\Desktop\CubeCSVDatabase\T76\CM_1683594434_1.cub.csv"
lkF = r"C:\Users\deran\Desktop\CubeCSVDatabase\T67\CM_1649191415_1.cub.csv"
lkG = r"C:\Users\deran\Desktop\CubeCSVDatabase\T67\CM_1649200801_1.cub.csv"
lkH = r"C:\Users\deran\Desktop\CubeCSVDatabase\T61\CM_1629912413_1.cub.csv"
lkI = r"C:\Users\deran\Desktop\CubeCSVDatabase\T61\CM_1629912119_1.cub.csv"
lkJ = r"C:\Users\deran\Desktop\CubeCSVDatabase\T52\CM_1617475099_1.cub.csv" #Bad GEO.
lkK = r"C:\Users\deran\Desktop\CubeCSVDatabase\T52\CM_1617478680_1.cub.csv"
lkL = r"C:\Users\deran\Desktop\CubeCSVDatabase\T52\CM_1617479398_1.cub.csv"

n0 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654399736_1.cub.csv"
n1 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654448409_1.cub.csv"
n2 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654401134_1.cub.csv"
n3 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654398683_1.cub.csv"
n4 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T69\CM_1654398195_1.cub.csv"
n5 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T85\CM_1721854264_1.cub.csv"
n6 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T85\CM_1721854459_1.cub.csv"
n7 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T93\CM_1753530947_1.cub.csv" #NO AXES
n8 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T93\CM_1753532797_1.cub.csv" #NO AXES
n9 = r"C:\Users\deran\Desktop\CubeCSVDatabase\T94\CM_1757663996_1.cub.csv" #NO AXES
nA = r"C:\Users\deran\Desktop\CubeCSVDatabase\T97\CM_1767300222_1.cub.csv" #NO AXES
nB = r"C:\Users\deran\Desktop\CubeCSVDatabase\T37\CM_1683599790_1.cub.csv"

oppositionCube = r"C:\Users\deran\Desktop\CubeCSVDatabase\T37\CM_1574127168_1.cub.csv"

simTest = r"C:\Users\deran\Desktop\DooseCSV\2012_A0.0_p000_colorCCD.Jcube.csv"

limby = r"C:\Users\deran\Desktop\CubeCSVDatabase\T76\CM_1683599790_1.cub.csv"

realCube = "CM_1574127168_1" #This is the "tester" cube by default. Y'know. For testing. 
#Insert any cube you want here if you need it for some reason. 
#Number code is recommended for pyvims.

import csv
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import random
#import mpl_interactions.ipyplot as iplt
import matplotlib.image as mpimg
import scipy.misc
from scipy import ndimage
from pyvims import VIMS
from matplotlib.colors import LogNorm
# Out:
# C:\Users\deran\AppData\Local\Temp\ipykernel_31992\2921003662.py:77: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.3)
#   import scipy.misc

# %%
# We need to ingest twice, once with each method. 

# %matplotlib ipympl

#File insertion goes here.
#Make sure to put the entire file path here. 
#You do not need to specify the axes file, it can be found automatically from this one.
filepath = oppositionCube #use the name of the cube you want in the above cell.

#Now we extract the axes file as well...
cubeAxesfp = filepath.removesuffix(".csv") + ".axes.csv"

#And you know what why not all the others as well.
cubeGeofpVIS = filepath.removesuffix(".cub.csv") + "_vis_geo.cub.csv" #This one is probably useless.
cubeGeofpIR = filepath.removesuffix(".cub.csv") + "_ir_geo.cub.csv"
cubeGeofpVISaxes = filepath.removesuffix(".cub.csv") + "_vis_geo.cub.axes.csv" #This one too.
cubeGeofpIRaxes = filepath.removesuffix(".cub.csv") + "_ir_geo.cub.axes.csv"
#Basically, we don't use axesfp if it's not needed.

cube = VIMS(realCube)

#Skeleton code nabbed from https://realpython.com/python-csv/
#We need to be able to handle both local and other cubes. 
#Pyvims can help us, but as I don't want to redo all the code we'll find a way to store
#it in the way the code understands.

#Step 1: use the axes to determine the size of what we're dealing with.

xAxisCube = []
yAxisCube = []
zAxisCube = []

xAxisGeoIR = []
yAxisGeoIR = []
zAxisGeoIR = []

cube = VIMS(realCube) #Loading this every time may not be helpful... find a way to conditionally load? 
#It is a very low time waster though, may not be worth it.

xAxisCube2 = []
yAxisCube2 = []
zAxisCube2 = []

xAxisGeoIR2 = []
yAxisGeoIR2 = []
zAxisGeoIR2 = []

#if (filepath == realCube):
#    cube = VIMS(filepath)
#    i,j,k = 0,0,0
    
#else: #Funnily enough, the database was under maintenance when I tried to do this. Hmm.
with open(cubeAxesfp) as csv_file: #remember to tab.
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            i = 0
            L = len(row)
            while (i < L-1):
                if (line_count == 0):
                    xAxisCube.append(row[i])
                elif (line_count == 1):
                    yAxisCube.append(row[i])
                elif (line_count == 2):
                    zAxisCube.append(row[i])
                i = i+1
            line_count += 1
with open(cubeGeofpIRaxes) as csv_file: #remember to tab.
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            i = 0
            L = len(row)
            while (i < L-1):
                if (line_count == 0):
                    xAxisGeoIR.append(row[i])
                elif (line_count == 1):
                    yAxisGeoIR.append(row[i])
                elif (line_count == 2):
                    zAxisGeoIR.append(row[i])
                i = i+1
            line_count += 1

i=0
zAxisGeoIR2.append(0) 
for x in cube.w:
    zAxisCube2.append(cube.w[i])
    i = i+1
i=0
while (i < cube.shape[1]):
    xAxisCube2.append(i)
    xAxisGeoIR2.append(i)
    i = i+1
i=0
while (i < cube.shape[2]):
    yAxisCube2.append(i)
    yAxisGeoIR2.append(i)
    i = i+1
i = 0
while (i < 8):
    zAxisGeoIR2.append(i)
    #No need to do VIS, quite unecessary.
    i = i+1
#wvlns: (alt: 2) contains the wavelengths, equivalent to our zAxis.
#Shape contains cube size. Probably wxy, but may be wyx? NB is bands (w) and NL is lines (x or y?)
#lat, lon: position! 
#ground_inc, ground_eme, ground_azi: incidence and emission AND azimuth
    
#We now have an x, y, and z axis. x and y axes are just ordinal, but the z axis contains wavelength in microns.
#The lengths of these arrays tell us how to extract the data.

cubeData = [[[0 for x in range(len(zAxisCube))] for x in range(len(yAxisCube))] for x in range(len(xAxisCube))]
geoIRData = [[[0 for x in range(len(zAxisGeoIR))] for x in range(len(yAxisGeoIR))] for x in range(len(xAxisGeoIR))]
cubeData2 = [[[0 for x in range(len(zAxisCube2))] for x in range(len(yAxisCube2))] for x in range(len(xAxisCube2))]
geoIRData2 = [[[0 for x in range(len(zAxisGeoIR2))] for x in range(len(yAxisGeoIR2))] for x in range(len(xAxisGeoIR2))]

with open(filepath) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    i, j, k = 0, 0, 0
    for row in csv_reader:
        while (i < len(xAxisCube)):
            cubeData[i][j][k] = float(row[i])
            if (math.isnan(cubeData[i][j][k])):
                cubeData[i][j][k] = 0 #We set nans to zero to allow plotting to take place, careful!
            elif (cubeData[i][j][k] < 0):
                cubeData[i][j][k] = 0 #Negative values are nonsense.
            elif (cubeData[i][j][k] > 1):
                cubeData[i][j][k] = 1 #Make saturation obvious? Keep it from overloading. 
            i = i + 1
        i = 0
        j = j + 1
        if (j >= len(yAxisCube)):
            j = 0
            k = k + 1
        line_count += 1
with open(cubeGeofpIR) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    i, j, k = 0, 0, 0
    for row in csv_reader:
        while (i < len(xAxisGeoIR)):
            geoIRData[i][j][k] = float(row[i])
            if (math.isnan(geoIRData[i][j][k])):
                geoIRData[i][j][k] = 0 #We set nans to zero to allow plotting to take place, careful!
            elif (geoIRData[i][j][k] < -1000):
                geoIRData[i][j][k] = 0 #The default value is an extremely negative number. Scrub it.
            i = i + 1
        i = 0
        j = j + 1
        if (j >= len(yAxisGeoIR)):
            j = 0
            k = k + 1
        line_count += 1

#Okay so read in the data from the PyVIMS cube. 
#The data itself is easy. Unfortunately we also need the GEO data, which is harder.
#If we want the same code to work every time, we need to get each geo value 
#to have the same values as a Jcube.
#Each entry of a Jcube GEO contains the following:
# 0: LAT, 1: LON, 2: Sample Resolution, 3: Line resolution, 4: Phase, 5: incidence, 
#6: emission, 7: North Azimuth, 8: Limb Impact Parameter
#Found in Detectors.c++ part of SRTC++ 
#Now we don't need all these values, some of them will just be zero. But they all need to be set.

i, j, k = 0,0,0
while (i < len(zAxisCube2)):
    j = 0
    while (j < len(xAxisCube2)):
        k = 0
        while (k < len(yAxisCube2)):
            cubeData2[j][k][i] = cube[i+97][j][k] 
            if (i == 0):
                        
                try:
                    c = round(cube.ground_lat[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][0] = cube.ground_lat[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][0] = 0.
                
                try:
                    c = round(cube.ground_lon[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][1] = cube.ground_lon[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][1] = 0.
                
                try:
                    c = round(cube.ground_res[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][2] = cube.ground_res[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][2] = 0.
                    
                geoIRData2[j][k][3] = 0.
                
                try:
                    c = round(cube.ground_phase[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][4] = cube.ground_phase[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][4] = 0.
                       
                try:
                    c = round(cube.ground_inc[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][5] = cube.ground_inc[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][5] = 0.

                try:
                    c = round(cube.ground_eme[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][6] = cube.ground_eme[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][6] = 0.
                        
                try:
                    c = round(cube.ground_azi[j][k]) #This should break if it isn't numeric.
                    #In fact this error is what gave us issues later.
                    geoIRData2[j][k][7] = cube.ground_azi[j][k]
                except:
                    #If not a number, zero it. 
                    geoIRData2[j][k][7] = 0.
                
                geoIRData2[j][k][8] = 0.
                
            if (math.isnan(cubeData2[j][k][i])):
                cubeData2[j][k][i] = 0 #We set nans to zero to allow plotting to take place, careful!
            elif (cubeData2[j][k][i] < 0):
                cubeData2[j][k][i] = 0 #Negative values are nonsense.
            elif (cubeData2[j][k][i] > 1):
                cubeData2[j][k][i] = 1 #Make saturation obvious? Keep it from overloading.                 
            k = k+1
        j = j+1
    i = i+1
#The data is now read in.
#all future programs in this notebook should be able to access xAxis, yAxis, zAxis and dataStorage.
#dataStorage is stored in xyz order, that is x, y, and wavelength. 

#helpful declarations
#Wavelength of windows in microns (um)
windowum = [0.933078, 1.08183, 1.27813, 1.59018, 2.01781, 2.69620, 2.79889, 5.00576]
#Now we need to dynamically find the indeces where this is true. 
windowInd = [0,0,0,0,0,0,0,0]
windowInd2 = [0,0,0,0,0,0,0,0]
i = 0
while (i < 8):
    j = 0
    while (j < len(zAxisCube)):
        #print(i, j, windowum[i], zAxisCube[j], windowInd[i])
        if (float(zAxisCube[j]) <= windowum[i] and float(zAxisCube[j+1]) >= windowum[i]):
            #if (windowum[i] - float(zAxisCube[j]) < float(zAxisCube[j+1]) - windowum[i]):
            windowInd[i] = j+1
                #This mess makes sure our index values match the "bestcolor" index numbers. 
                
            #else:
                #windowInd[i] = j+1
            j = len(zAxisCube)
        j = j + 1
    i = i+1
print(windowInd)
i = 0
while (i < 8):
    j = 0
    while (j < len(zAxisCube2)):
        #print(i, j, windowum[i], zAxisCube[j], windowInd[i])
        if (float(zAxisCube2[j]) <= windowum[i] and float(zAxisCube2[j+1]) >= windowum[i]):
            #if (windowum[i] - float(zAxisCube[j]) < float(zAxisCube[j+1]) - windowum[i]):
            windowInd2[i] = j+1
                #This mess makes sure our index values match the "bestcolor" index numbers. 
                
            #else:
                #windowInd[i] = j+1
            j = len(zAxisCube2)
        j = j + 1
    i = i+1
print(windowInd2)
#Later found out that bestcolor doesn't use the "closest" one. Hmm. 
    
def indexFromWav(wav):
    index = 0
    j = 0
    while (j < len(zAxisCube)):
        if (float(zAxisCube[j]) < wav and float(zAxisCube[j+1]) > wav):
            if (wav - float(zAxisCube[j]) < float(zAxisCube[j+1]) - wav):
                index = j
                #Have to make sure we pick the closest point, not just the "lower" one.
            else:
                index = j+1
            j = len(zAxisCube)
        j = j + 1    
    return index

def indexFromWav2(wav):
    index = 0
    j = 0
    while (j < len(zAxisCube2)):
        if (float(zAxisCube2[j]) < wav and float(zAxisCube2[j+1]) > wav):
            if (wav - float(zAxisCube2[j]) < float(zAxisCube2[j+1]) - wav):
                index = j
                #Have to make sure we pick the closest point, not just the "lower" one.
            else:
                index = j+1
            j = len(zAxisCube2)
        j = j + 1    
    return index
    
#image dimensions are fungible. Calculate them.  
xDim = 0
yDim = 0
if (len(xAxisCube) > len(yAxisCube)):
    yDim = 9 
    xDim = 9/(len(xAxisCube)/len(yAxisCube))
else:
    xDim = 9
    yDim = 9/(len(yAxisCube)/len(xAxisCube))
#This may seem backward, but transpositions occur so...

xDim2 = 0
yDim2 = 0
if (len(xAxisCube2) > len(yAxisCube2)):
    yDim2 = 9 
    xDim2 = 9/(len(xAxisCube2)/len(yAxisCube2))
else:
    xDim2 = 9
    yDim2 = 9/(len(yAxisCube2)/len(xAxisCube2))
#This may seem backward, but transpositions occur so...


    
print(np.amax(cubeData))
print(np.amin(cubeData))
print(np.amax(cubeData2))
print(np.amin(cubeData2))

print(np.amax(geoIRData))
print(np.amin(geoIRData))
print(np.amax(geoIRData2))
print(np.amin(geoIRData2))
# Out:
# [80, 108, 120, 139, 165, 206, 212, 344]
# [3, 12, 24, 43, 69, 110, 116, 248]
# 0.286067
# 0.0
# 0.19729386270046234
# 0.0
# 359.99939
# -11.575551
# 182.87114856417884
# -11.602709225068349

# %%
#Now that we've read everything in, everything of relevance needs to be printed and analyzed and compared to be SURE about what's going on.
#Our cube, PyVIMS cube, and then difference.
#Three displayable at once in a 3x3 grid.

# %matplotlib ipympl
fig, axs = plt.subplots(3,3, figsize = (10,10), layout = "tight") 

temp = np.transpose(cubeData)
temp2 = np.transpose(cubeData2)
p = 0
for plane in temp2:
    x=0
    for xPlane in plane:
        y=0
        for yPlane in xPlane:
            temp2[p][y][x] = cubeData2[y][x][p]
            y=y+1
        x=x+1
    p=p+1
geoTemp = np.transpose(geoIRData)
geoTemp2 = np.transpose(geoIRData2)
p = 0
for plane in geoTemp:
    x=0
    for xPlane in plane:
        y=0
        for yPlane in xPlane:
            geoTemp2[p][y][x] = geoIRData2[y][x][p]
            y=y+1
        x=x+1
    p=p+1

#Windows are, according to lambertian_wholedisk:
#0.933078, 1.08183, 1.27813, 1.59018, 2.01781, 2.69620, 2.79889, 5.00576

f1 = 1
c1 = axs[0,0].imshow((temp[windowInd[f1]]), cmap="copper")
c2 = axs[0,1].imshow((temp2[windowInd2[f1]]), cmap="copper")
c3 = axs[0,2].imshow(temp[windowInd[f1]] - temp2[windowInd2[f1]], cmap="copper")

f2 = 4
c4 = axs[1,0].imshow(geoTemp[f2], cmap="copper")
c5 = axs[1,1].imshow(geoTemp2[f2], cmap="copper")
c6 = axs[1,2].imshow(geoTemp[f2] - geoTemp2[f2], cmap="copper")

c7 = axs[2,0].imshow((temp[windowInd[6]]), cmap="copper")
c8 = axs[2,1].imshow((temp[windowInd[7]]), cmap="copper")
c9 = axs[2,2].imshow((temp[windowInd[7]]), cmap="copper")

fig.colorbar(c1, ax=axs[0][0])
fig.colorbar(c2, ax=axs[0][1])
fig.colorbar(c3, ax=axs[0][2])
fig.colorbar(c4, ax=axs[1][0])
fig.colorbar(c5, ax=axs[1][1])
fig.colorbar(c6, ax=axs[1][2])
fig.colorbar(c7, ax=axs[2][0])
fig.colorbar(c8, ax=axs[2][1])
fig.colorbar(c8, ax=axs[2][2])
#fig.colorbar(c4, ax=cax, label='High') 
#fig.tight_layout(pad=1.0)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
