# %% [markdown]
# # TITAN LIMB TEMPORAL ANALYSIS... analysis.
#
# ## Why does analysis have to be in the title...?
#
# ### Anyway this is my attempt to put all ideas into their boxes so we can see what we need from Aadvik.

# %% [markdown]
# The ultimate goal here is to fully understand the paper and figure out what holes exist in it, and what needs to be filled by Aadvik and what we can fill on our own.

# %% [markdown]
# ## ABSTRACT
#
# The abstract outlines this:
#
# - Analyze evolution of brightness profiles
# - Insight into vertical atmospheric structure
# - Wavelength and Time checking.
# - Track atmosphere layer developments.
# - limb brightening varies with wavelength and time.
# - understanding of underlying seasonal dynamics.
#
# I don't recall exact tracking of layer developments, nor the understanding of underlying seasonal dynamics, but thsoe sections might just be missing.

# %% [markdown]
# ## INTRODUCTION
#
# This was written by Jason, so is probably the best section of the paper to see what all of it is supposed to be about.
#
# We perhaps need a term that describes both limb darkening and brightening.
#
# The introduction claims we are reporting observed limb darkening and brightening parameters for Titan's haze. The introduction is pretty serious that this is just preliminary, and makes no attempt at detailed analysis. No mention of tracking layer developments, or understanding of underlying seasonal dynamics.
#
# Also, "we suggest that it may be possible" this is far more uncertain than the rest of the paper...
#
# Feel like the introduction needs a paragraph about what we actually DID. But otherwise fine. Mostly just catchup on what is already known.

# %% [markdown]
# ## OBSERVATIONS
#
# Where we answer where the observations come from.
#
# Description of VIMS data use seems fine.
#
# ### SUBSEC: CUBE SELECTION
#
# I do not think this heading is necessary, just have it be another paragraph as part of observations.
#
# - simultaneous observations from visible and IR
# - low phase angle (less than 30 deg)
# - full disc coverage with high limb visibility
# - sufficient spatial resolution (200 km/pixel)
# - sub-scpacecraft longitude between 20 and -20 lat.
# - sufficient time cadence across mission.
#
# The main issue here is "expansion of criteria." We NEED to know if this means expansion to the criteria already listed above, or not. And precisely how.
#
# I will note that the big table does not showcase cube names, which we should grab, if possible. Can we ask for the specific cubes used?
#
# Commented out notes:
# - mention VIMS and preprocessing
# - Talk about separation of surface and limb (rq from pyvims. What is that? look it up.)
# - Looking at shape of curve, not just the limb (changes). (Does this not mean physical shape, but the shape of the graph?)
# - Example picture of limb darkening and limb brightening (a new figure that isn't present. Not aadvik required).

# %% [markdown]
# ## METHODS
#
# ### SUBSEC: SRTC++
#
# This is the section Jason and I need to do. Nothing is here presently. This is fine.
#
# ### SUBSEC: IMAGE PROCESSING
#
# The flowchart figure needs a caption.
#
# CITE: paper that talks about VIMS-V destriping here
#
# CITE: paper to cite on known Titan surface window wavelengths. (a.k.a. do not use the windows to analyze the signal, as the ground can interfere.)
#
# CITE: the paper that shows the north-south boudnary locaiton, perhaps the previous paper by "us?"
#
# Transect method described, not explained (or cited)
#
# Transect fig mentioned. I don't see it.
#
# comments:
#
# - takl about using only lower wavelenght - as accuract was super low- degradiation in the VIMS-IR data was significant. (This is completely missing, probably need Aadvik's input on this)
# - Trust mapping - do mean/std instead of std/mean FIGURE HERE, and do the writeup as well.
# - reference quad figures here - we should show the transects themselves, and how the fits are generally effective (clearly we are missing an example of the actual transect).
#
# ### SUBSEC: QUADRATIC LIMB DARKENING LAW REGRESSION
#
# An equation, neat! And propercly cited, too!
#
# CITE: Levenberg-Marquardt algorithm (yes as it isn't explained).
#
# Quandrant fig mentioned. I don't see it.
#
# Need to undestand what values are the limb brightening and darkening, and why the zero on Figure 4 doesn't seem to match right. Need a clearer explanation here--can perhaps reverse engineer it though.
#
# ### SEBSEC: COMPILED ANALYSIS
#
# This section does not exist, and it describes how the VIMS and SRTC++ data was combined. Looking at the figures... I don't think this was even done? Having finally gone over it, there's no figures that show anything past the direct analysis.
#
# If we DO need this, then Aadvik would have to write it. But if we don't... well then. We could just do this ourselves!

# %% [markdown]
# ## RESULTS
#
# Figure 5 is the primary result here, sensible, showcases differences in it.

# %% [markdown]
# ## Conclusion
#
# This is empty and we need to do it, naturally.
