# %% [markdown]
# # Geometric Algebra
#
# ## Black Magic That's Actually Useful
#
# ### Trust me it is. I said trust me. Stop running.

# %% [markdown]
# # PART 0: Sudgylacmoe's Introduction
#
# https://www.youtube.com/watch?v=60z_hpEAtD8
#
# Let's combine everything in physics into one big thing! An oberview! This is just the launching board from which we go to a more in depth set of videos. I think this will be useful so I want it in my head and so thus am taking NOOOOOOOTES~!
#
# Prerequisites: scalars, vector definitions, vector bases,
#
# Hierarchy: Scalar, Vector, Bivector, Trivector, k-vector.
#
# Bivector is determined by orientation and area, not shape.
#
# vector dot vector is scalar (inner or dot product)
#
# vector outer vector is bivector (outer product)
#
# outer product just adds dimensions. Bivector outer vector is trivector.
#
# Unit bivectors are outer products of unit vectors. (By the way outer product symbol is ^ but big)
#
# Geometric Product: u dot v + u outer v = uv.
#
# uu = magnitude squared.
#
# Can define inner and outer products in term of geometric product.
#
# Fun things can be done with unit vectors: their inner product is zero so they are only outer products in geometric product, and the geometric product anticommutes for them. For two vectors, the outer product kind of looks like the cross product.
#
# The geometric product is, in total, a multivector. For 2D we have (a + bx^ + cy^ + dx^y^)
#
# The highest order vector object from the unit vectors in our space can be thought of as "i". Also known as the Pseudoscalar.
#
# Geometric product can create rotations of the angle betwen them. Using unit vectors removes the scaling effect.
#
# 3D has eight components multivector. The trivectors are the pseudoscalars. They are not rotations, but they are commutable.
#
# The cross product sucks.
#
# We can get the Pauli Spin Matrices out of this. And quaternions come out for free.
#
# The 3D rotor can be generated, but you have to rotate by halves to get the general form. (Trivectors keep popping out). Also you get spinors with these rotors.
#
# Adjust Maxwell's Equations! GradF = J/cepsilon_naut.
#
# https://www.youtube.com/watch?v=0bOiy0HVMqA
#
# And the addendum just to be sure.
#
# To explain the geometric, we can think  of it as adding together the multiplication of perpendicular and paralell parts, even though the two parts produce different objects.
#
# Perpendicular things join, paralell things cancel.
#
# For 4D dimensions and up, we can end up with cross terms between the inner and outer product.
#
# Make vector sandwiches to deal with rotations.
#
# Okay with all that spew let's move on to the *actual* set of tutorials.

# %% [markdown]
# Good overview paper: https://www.mrao.cam.ac.uk/~clifford/publications/abstracts/dll_millen.html. Has no math, is descriptive.
#
# https://www.mrao.cam.ac.uk/~clifford/publications/abstracts/imag_numbs.html has more actual math.

# %% [markdown]
# # PART I: Fundamentals and Another Look at Complex Numbers
#
# https://youtu.be/PNlgMPzj-7Q?si=jZKcLzP2Sefu_rdi
#
# Declare a 2D vector space with the usual perpendicular unit vectors, but call those vectors $e_1$ and $e_2$ rather than using the usual hats, even though this is just x and y. (Note that it doesn't have to be though).
#
# We define minus signs as the opposite directions of the unit vectors, and every vector in this space is $ae_1 + be_2$. And with that we have declared our space.
#
# DOT PRODUCT $u \cdot v = u_1v_1 + u_2v_2$. For orthogonal, the dot product goes to zero. Commutative. And self dot product is the magnitude.
#
# WEDGE PRODUCT $u \wedge v$, creates a paralellogram with circulation (bivector). The circulation is from u to v.
#
# $ u \wedge u = 0; u \wedge v = - v \wedge u $ (anticommutative). Opposite circulation is considered negative.
#
# To actually figure out what object we get, we can use these properties we determined geometrically to get a result.
#
# $$ u = u_1e_1 + u_2e_2 $$
# $$ v = v_1e_1 + v_2e_2 $$
# $$ u \wedge v = (u_1e_1 + u_2e_2) \wedge (v_1e_1 + v_2e_2) $$
#
# We note that while it wasn't exatly specified before, we can still distribute this out like we were FOILing it, or distributing. Let's just assume it works for now even though it isn't obvious it would with the rules we've set out. (However scalars moving in and out is obvious.)
#
# $$ = u_1v_1(e_1 \wedge e_1) + u_1v_2(e_1 \wedge e_2) + u_2v_1(e_2 \wedge e_1) + u_2v_2(e_2 \wedge e_2) $$
#
# Wedge product with itself is zero, and by flipping the product on the second of the remaining terms we arrive at
#
# $$ = (u_1v_2 - u_2v_1) (e_1 \wedge e_2) $$
#
# Notably that this is the *determinant*. This is equal to the area of the bivector paralellogram. The magnitude is also the cross product.
#
# SO what if we just ADDED the two parts together? Thus...
#
# $$ uv = u \cdot v + u \wedge v $$
#
# This is the odd step that you think wouldn't help but TOTALLY DOES.
#
# $uu = |u|^2$
#
# For perpendicular:
#
# $uv = u \wedge v$
#
# In general the geoproduct is not commutative or anticommutative.
#
# We feed in two 1D objects nad get a 0D and a 2D object out.
#
# Using our generic vectors again, what does this all expand into?
#
# $$ uv = (u_1v_1 + u_2v_2) + (u_1v_2 - u_2v_1) (e_1 \wedge e_2) $$
#
# Now what if we apply this to the unit vectors directly?
#
# $$ e_1e_1 = e_1 \cdot e_1 + e_1 \wedge e_1 = e_1 \cdot e_1 = 1 $$
#
# $$ e_1e_2 = e_1 \cdot e_2 + e_1 \wedge e_2 = 0 + e_1 \wedge e_2 $$
#
# So $e_1e_2 = -e_2e_1$ perhaps unsurprisingly.
#
# But now... what of $(e_1e_2)^2$?
#
# $$ e_1e_2e_1e_2 = -e_1e_2e_2e_1 = -e_1e_1 = -1 $$
#
# Ah yes the properties if i!
#
# Anyway the final result we get is scalars, two vectors, and the bivector "i" or "I". So 2D geometric algebra is 4D, as you write out the multivectors as {scalar, $e_1$, $e_2$, I}.
#
# Back up and consider imaginary numbers as we know them for a minute.
#
# $$ e^{\theta i} (a+bi) = acos\theta - bsin\theta + (asin\theta + bcos\theta)i $$
#
# This is a rotation. However, while we often think of complex numbers as a+bi, we can also think of them as a+b$e_1e_2$, where is now a bivector! For those of us who like abstract algebra, this is an isomorphism.
#
# Thus we can do rotations in 2D geometric algebra like so. Take a vector u which is $ae_1 + be_2$, then do ui.
#
# $$ (ae_1 + be_2)e_1e_2 = ae_1e_1e_2 + be_2e_1e_2 = ae_2 - be_2e_2e_1 = ae_2 - be_1 $$
#
# Which is the same as having rotated the vector u 90 degrees counterclockwise. Note that we had to multiply on the right. Multiplying on the left gives a different result:
#
# $$ e_1e_2(ae_1 + be_2) = ae_1e_2e_1 + be_1e_2e_2 = - ae_1e_1e_2 + be_1 = - ae_2 + be_1 $$
#
# It's the rotation in the other direction.
#
# We can ask "what would give us an arbitrary angle rotation?" Well we know that imaginary numbers are isomorhic, so how do we rotate imaginary numbers?
#
# $$ e^{\theta i} (a+bi) = (cos\theta + sin\theta i) (a+bi) = acos\theta - bsin\theta + (asin\theta + bcos\theta)i $$
#
# Which as it turns out does map directly to the geometric algebra space.
#
# $$ (cos\theta + sin\theta e_1e_2)(ae_1 + be_2) = cos\theta ae_1 +cos\theta b e_2 + sin\theta a e_1e_2e_1 + sin\theta b e_1 e_2 e_2 = cos\theta ae_1 +cos\theta b e_2 - sin\theta a e_2 + sin\theta b e_1 = (cos\theta a + sin\theta b)e_1 + (cos\theta b -sin\theta a)e_2$$
#
# Doing it the other way rotates the other way.
#
# $$ (ae_1 + be_2)(cos\theta + sin\theta e_1e_2) = cos\theta ae_1 +cos\theta b e_2 + sin\theta a e_1e_1e_2 + sin\theta b e_2 e_1 e_2 = cos\theta ae_1 +cos\theta b e_2 + sin\theta a e_2 - sin\theta b e_1 = (cos\theta a - sin\theta b)e_1 + (cos\theta b + sin\theta a)e_2$$
#
# Of course we can still choose to write this in an exponential form, $e^{\theta e_1e_2}$ if we wish. Using "i" or "I" as desired as well. Note that this means the rotation is given by a bivector, specifically the unit bivector in 2D space. This makes sense as a bivector is an area with a *circulation*, naturally that circulation could introduce actual rotations.

# %% [markdown]
# # PART II: Vector Projection and Reflection
#
# https://youtu.be/ERpcSJzX448?si=WYSzMcii5LeZ2uiD
#
# A review of grades: scalars are grade-0, vectors are grade-1, and bivectors are grade-2, which we can think of as the physical dimensionality. However, the actual dimensionality of the space we are doing math in is 4, as we have scalrs, two vectors, and a bivector can be used to describe things, 1+2+1=4.
#
# We have an inverse property now:
#
# $$ uu = |u|^2 \Rightarrow \frac{uu}{|u|^2} = 1 \Rightarrow u^{-1} = \frac{u}{|u|^2} $$
#
# To be clear about a geometric product property, for paralell vectors it is the dot product, for perpendicular it is the wedge product. One special property is that the dot product commutes, the wedge product anticommutes, so signs are going to go flying everywhere.
#
# One thing we can do with this is get some more relations out of the general geometric product:
#
# $$  uv = u\cdot v + u \wedge v $$
# $$  vu = v\cdot u + v \wedge u $$
# $$ \Rightarrow vu = u\cdot v - u\wedge v $$
#
# We can actually combine these relations as there are correlations!
#
# $$ 2u\cdot v = uv - u\wedge v + vu + u\wedge v$$
# $$ \Rightarrow u\cdot v = \frac12(uv + vu) $$
# $$ 2u\wedge v = uv - u\cdot v - vu + u\cdot v $$
# $$ \Rightarrow u\wedge v = \frac12(uv-vu) $$
#
# These can be useful as regularly the geometric prodcut, which is arguably more fundamental, is known while the individual products arne't really.

# %% [markdown]
# Now, let's talk about projection and rejection.
#
# ![image.png](attachment:image.png)
#
# Here, the projection of u onto v is $u_{||}$ while the rejection is $u_{\perp}$, just to be clear about it. Note that $u = u_{||} + u_\perp$, so every vector will have a projected and rejected component. We can put this in the langauge of the geometric product:
#
# $$ uv = u_{||}v + u_{\perp} v $$
#
# As we have perpendicular and paralell vectors we can change orders and signs like so:
#
# $$ uv = u_{||}v - v u_{\perp} $$
#
# Now lets mess with some algebra a bit...
#
# $$ \Rightarrow uv = u_{||}v - v(u - u_{||}) $$
# $$ \Rightarrow uv = u_{||}v - vu + vu_{||} $$
# $$ \Rightarrow uv = u_{||}v - vu + u_{||}v $$
# $$ \Rightarrow uv + vu = 2u_{||}v $$
# $$ \Rightarrow \frac12(uv + vu) = u_{||}v $$
#
# Hey this is familiar this means $u\cdot v = u_{||} v$.
#
# A very similar proof shows that $u\wedge v = u_\perp v$. Which in the interests of completeness I will bother to show in full as now I have doubts the signs actually work out, oh well.
#
# $$ uv = u_{||}v - v u_{\perp} $$
# $$ \Rightarrow uv = (u-u_\perp)v - vu_\perp $$
# $$ \Rightarrow uv - uv = -u_\perp v - vu_\perp $$
# $$ \Rightarrow uv - uv = -u_\perp v - vu_\perp $$
# $$ \Rightarrow 0 = 0 $$
#
# Ah. I see. Well then. Try flipping before substituting.
#
# $$ uv = vu_{||} - v u_{\perp} $$
# $$ \Rightarrow  uv = v(u - u_\perp) - vu_\perp $$
# $$ \Rightarrow  uv - vu = - 2vu_\perp  $$
# $$ \Rightarrow  \frac12(vu - uv) = vu_\perp  $$
# $$ \Rightarrow  -v\wedge u = vu_\perp  $$
# $$ \Rightarrow  v\wedge u = u_\perp v $$
#
# So it is true it's just that the proof has an easy pitfall to fall into of 0=0. Got to be careful.
#
# Anyway this means that our dot product is the same as the paralell geometric product, and the wedge is the perpendicular. Which. Yeah that's kind of obvious given the properties we already know, actually.
#
# We can get a bit more than this though. Using the inverse rule...
#
# $$ u_{||} = (u \cdot v) v^{-1} $$
# $$ u_\perp = (u \wedge v) v^{-1} $$
#
# If we expand the inverses we get the more familiar forms.
#
# $$ u_{||} = \frac{(u \cdot v)}{|v|^2} v $$
# $$ u_\perp = \frac{(u \wedge v)}{|v|^2} v $$
#
# ALTERNATIVELY we could prove this by noting
#
# $$ u = u_{||} + u_\perp $$
# $$ \Rightarrow u_\perp = u- u_{||} $$
# $$ \Rightarrow u_\perp = u - (u\cdot v)v^{-1} $$
# $$ \Rightarrow u_\perp = (uv-u\cdot v)v^{-1} $$
# $$ \Rightarrow u_\perp = (u \wedge v)v^{-1} $$

# %% [markdown]
# We notably have not done reflection yet. But in the nature of projection and rejection, it's actually qutie simple:
#
# ![image.png](attachment:image.png)
#
# Which is to say, reflecting u across v is the same as saying $u' = u_{||} - u_\perp$.
#
# With some finagling, we can show
#
# $$ vu' = vu_{||} - vu_\perp $$
# $$ \Rightarrow vu' = u_{||}v + u_\perp v $$
# $$ \Rightarrow vu' = uv $$
# $$ \Rightarrow u' = v^{-1}uv $$
#
# So reflections are SANDVICHES!

# %% [markdown]
# Now we have ourselves an actual exercise. What happens if we reflect twice? That is, we have u, v, and w, and then do:
#
# $$ w^{-1}v^{-1}uvw $$
#
# Well, intuitively since it's two reflections, naturally we should be able to do this with *one* refleciton. If this is true, then we would have $w^{-1}v^{-1} = (vw)^{-1}$. Except... we haven't defined the inverse of a geometric product yet. Perhaps, though, we can actually start by doing that?
#
# A geometric product can produce an object of $[1,e_1,e_2,e_1e_2]$. Ah, but while I happen to know the geometric product is defined for full multivectors, we only have it defined for vectors here. Alas... but wait! We can show what happens when we multiply them by each other! Just remove u!
#
# $$ w^{-1}v^{-1}vw $$
#
# Since the order of multiplication doesn't matter, well, the vs vanish, then the ws vanish, which means for sure that $w^{-1}v^{-1} = (vw)^{-1}$. Hah! Even without knowing precisely how to invert a multivector we have shown that it is possible AND occuring here. However, this does not yet prove we can simply do the transformation with a single reflection should we wish, as there could be a bivector component in that inverse. We're not *done*, but this is useful to know.
#
# Trying to do it the long way quickly became far too hariy to seem right. So let's try something else: transformations.
#
# $$ w^{-1}v^{-1}uvw = \frac{1}{|v|^2|w|^2}wvuvw = \frac{1}{|v|^2|w|^2}(w\cdot v + w \wedge v)u(v\cdot w + v \wedge w)$$
# $$ = \frac{1}{|v|^2|w|^2}(v\cdot w - v \wedge w)u(v\cdot w + v \wedge w) $$
# $$ = \frac{1}{|v|^2|w|^2}[(v\cdot w)u(v\cdot w) + (v\cdot w)u(v \wedge w) - (v\wedge w)u(v\cdot w) - (v\wedge w)u(v\wedge w)] $$

# %% [markdown]
# Let's think about what these terms are. A vector times two scalars is a vector. A vector times a scalar and a bivector is a vector (in 2D  space), and a vector times two bivectors will end up a vector agian. So we know for sure that the result here is going to be transforming u from one vector into another. However, to prove that the double reflection is the same as one reflection, we need to show that in the end u has the same *magnitude* as previously. That's the part I'm unsure on...
#
# There's actually a simple way to do this. We know u is of magnitude u. We know $v^{-1}uv$ is also of magnitude u. Thus surrounding it again by w won't change the magnitude.
#
# So, with these three results: the magnitude is conserved, the result is a vector, and the two sides are inverses of each other, we can say that the double reflection results in something that can be done with a *single* reflection. I hope that was what we needed to answer!

# %% [markdown]
# # PART III: Some Trigonometry
#
# https://youtu.be/lkhBcWtFxKU?si=b3-NGRpG6iOhZ4n0
#
# So now that we did that annoying problem here's actually another way to look at things that might have helped. First of all this is familiar:
#
# $$ u \cdot v = |u||v|cos\theta $$
#
# But this may not be:
#
# $$ u \wedge v = |u||v|sin\theta e_1e_2 $$
#
# These two things would have made it more evident that the constants canceled and the magnitude did not change. Oh well. We can apply this to the full geometric product as well.
#
# $$ uv = |u||v|e^{\theta e_1e_2} $$
#
# With this let's consider some trigonometry. First, let's create a triangle of vectors:
#
# ![image.png](attachment:image.png)
#
# So here we have A=B+C. We can with some finagling show:
#
# $$ B \wedge A = (A-C) \wedge A = A\wedge A - C \wedge A = -C \wedge A = A \wedge C $$
#
# So $B \wedge A = A \wedge C$. Interesting. Geometrically this says the extended paralellograms from B and C have the same area. This essentially IS the law of sines, though if we want it in the more familiar form:
#
# $$ B \wedge A = A \wedge C \Rightarrow |B||A|sin\gamma e_1e_2 = |A||C|sin\beta e_1e_2 $$
# $$ \Rightarrow basin\gamma = acsin\beta \Rightarrow bsin\gamma = csin\beta$$
# $$ \Rightarrow \frac{sin\beta}{b} = \frac{sin\gamma}{c} $$
#
# You can also extend this to show that it's also equal to $\frac{sin\alpha}{a}$.
#
# For the law of cosines, let's start with the expression for C.
#
# $$ C = A-B \Rightarrow C^2 = (A-B)^2 \Rightarrow C^2 = A^2 + B^2 - AB - BA $$
# $$ \Rightarrow C^2 = A^2 + B^2 - 2A\cdot B \Rightarrow c^2 = a^2 + b^2 - 2abcos\gamma $$
#
# Thus the law of cosines again. We will be discovering that so, so much we take for granted can be derived *from* geometric algebra.

# %% [markdown]
# # PARV IV: Linear Algebra and Cramer's Rule
#
# https://youtu.be/dnzUgDl43rQ?si=UK4fLzCOq1MvxAbA
#
# What else can we get from this?
#
# Well say we are solving a linear combination equation.
#
# $$ a_1x + b_1y = c_1 $$
# $$ a_2x + b_2y = c_2 $$
#
# Which we can write with vectors as
#
# $$ x\vec a + y \vec b = \vec c $$
#
# So, how to we solve for x and y then with geometric algebra? Well, we wedge it.
#
# $$ x\vec a \wedge \vec b + y \vec b \wedge \vec b = \vec c \wedge \vec b $$
# $$ \Rightarrow x\vec a \wedge \vec b = \vec c \wedge \vec b $$
#
# Of course solving for x here appears to need an inverse... oh or we can just divide (assuming the result isn't zero).
#
# $$ \Rightarrow x = \frac{\vec c \wedge \vec b}{\vec a \wedge \vec b} $$
#
# We can do this since the division is over a bivector, so really what we end up with is the "area ratio" between the two, leaving a sclaar. Also known as UNITS WORK OUT!
#
# Similarly for y we get $y = \frac{\vec a \wedge \vec c}{\vec a \wedge \vec b}$
#
# This is all entirely arbitrary. Neat!

# %% [markdown]
# Let's work out an arbitrary wedge product... but do it from the matrix form of linear combinations so we can find something new out.
#
# $$ A = \begin{bmatrix}
# a_1 & b_1 \\
# a_2 & b_2 \end{bmatrix} $$
#
# Let's do the wedge product between a and b.
#
# $$ \vec a \wedge \vec b = (a_1e_1 + a_2e_2)\wedge(b_1e_1 + b_2e_2) = a_1b_2(e_1\wedge e_2) + a_2b_1(e_2 \wedge e_1)$$
# $$ = (a_1b_2 - b_1a_2) (e_1 \wedge e_2) = det[A] e_1e_2 $$
#
# This is the familiar 2x2 matrix determinant. Which is usually just some mysterious number but now we have a way to derive it. (But what of higher order determinants?)
#
# If we replace wedge products with determinants we get Cramer's rule. In short cramer's rule is
#
# $$ x_i = \frac{det[A_i]}{det[A]} $$
#
# The specifics of how this work is irrelevant to our purposes, as it involves some linear algebra. Our victory here is that we can get the same result from geometric albegra without finagling with the normal proof for Cramer's rule.
#
# A note on the determinant = 0 case. Since the determinant is an outer product, and an outer product is the paralellogram area, that implies that a det=0 case would be between two vectors that are parallel and thus have no wedge product. Visualization power, activate!

# %% [markdown]
# # PART V: Two Reflecitons is a Rotation
#
# https://youtu.be/Hy2gbdbrJZ8?si=jMkZXjQS9OBVkiUY
#
# Okay so you know that challenge problem that was done? Yeah, we're returning to it, this video basically gives the solution.
#
# $$ w^{-1}v^{-1}uvw $$
#
# Now earlier we showed that this is also equivalent to a single reflection. The goal is to show that this is ALSO equivalent to a single rotation.
#
# Now this makes sense: as long as a line goes through the origin (which it has to if we're reflecting across a vector) then the reflection itself is just a rotation. This *logically* makes sense. It also does mathematically to: any vector of the same magnitude as a nother can be transformed to it via a rotation, no exceptions. Refleciton does NOT adjust magnitude. So reflections are rotations and rotaitons are reflections, and in 2D space this is always true for *vectors*.
#
# Now the reason this realization is so useful is because it allows us to use double reflections to create a rather intuitive rotation formula that will apply to higher dimensions. We also note that our proof of the inversing did in fact come in handy, heh.
#
# $$ w^{-1}v^{-1}uvw = (vw)^{-1}uvw = \frac{1}{|v||w|}e^{-\theta e_1e_2} u |v||w| e^{\theta e_1e_2} = e^{-\theta e_1e_2} u e^{\theta e_1e_2} $$
#
# Behold the rotaiton SANDVICH.
#
# This is in fact superior to our previous answer not because it's more correct--ours was still right--but this result is a specific usable result. We stated that a single reflection existed, NOT what it actually WAS. Here though we have a specific rotaiton that does the double reflection. Furthermore we can actually...
#
# $$ e^{-\theta e_1e_2} u e^{\theta e_1e_2} = u e^{\theta e_1e_2} e^{\theta e_1e_2} = u e^{2\theta e_1e_2} $$
#
# Which is to say the double refelction is a double rotation through the angle between the two reflection vectors. Note that if the reflection vectors are the same, they have zero angle, and the double reflection results in no movement! In essence this is merely more useful. Naturally a double rotation can also be accomplished with a reflection of some kind.

# %% [markdown]
# # PART VI: Kepler Problem 1
#
# ## Oh no we're gonna be here a while...
#
# https://youtu.be/VApO4qUgAYY?si=yPs58UssWnoctIwM
#
# Also known as the Two-Body problem! Let's solve it with geometric algebra!
#
# ![image.png](attachment:image.png)
#
# The situation, as we have it, is gravity. We have some relations here:
#
# $$ \vec r = \vec r_2 - \vec r_1 $$
#
# Due to LaTeX being annoying we can't use both vector symbols and dots, so just remember that quantities here are vectors when dotted.
#
# And from F=ma we can produce:
#
# $$ \ddot r_1 = \vec F_{12} / m_1 $$
# $$ \ddot r_2 = \vec F_{21} / m_2 $$
#
# And from Newton's Third Law:
#
# $$ \vec F_{12} = -\vec F_{21} $$
#
# So we can say
#
# $$ \ddot r_1 = \vec F_{12} / m_1 $$
# $$ \ddot r_2 = - \vec F_{12} / m_2 $$
#
# Define $\hat r$ to be the unit vector of $\vec r$. With the law of gravity we use
#
# $$ \vec F_{12} = G \frac{m_1m_2}{r^2}\hat r $$
#
# And thus
#
# $$ \ddot r_1 = G \frac{m_2}{r^2}\hat r $$
# $$ \ddot r_2 = - G \frac{m_1}{r^2}\hat r $$
#
# And also by taking derivatives
#
# $$ \ddot r = \ddot r_2 - \ddot r_1 $$
# $$ \Rightarrow \ddot r = - \frac{G(m_1+m_2)}{r^2} \hat r $$
# $$ \Rightarrow \ddot r = - \frac{\mu}{r^2} \hat r $$
#
# Where $\mu$ is just there for bookkeeping and is known as the gravitational parameter.
#
# There has been no geometric algebra yet. This is just the radial component of our problem.

# %% [markdown]
# We'll also be needing the angular momentum:
#
# $$ \vec L = \vec r \times \vec p $$
#
# However the cross product is really annoying and is inherently three dimensional. What if we really do wish to restrict ourselves to 2D? Well, we can do that! With GEOMETRIC ALGEBRA! You can probably see how one might represent the cross product using bivectors if you are familiar with the cross product. Otherwise just strap in and let's go!
#
# So, define our coordinates. Let $\vec r$ be the vector from the pivot, and $\dot r$ be the direction of motion. We can create a bivector from this:
#
# $$ H = \vec r \wedge \dot r $$. Naturally this does, in fact, circulate in the direction of rotation. For circular motion it's also easy to see that nothing particuarly changes here. However, now we need to take the derivative of a wedge product. One might think it odd but the product rule still applies here.
#
# $$ \dot H = \dot r \wedge \dot r + \vec r \wedge \ddot r = \vec r \wedge \ddot r $$
#
# Now, remember what we showed in the previous part about $\ddot r$ pointing in the -r direction? Well paralell wedge products are zero. This means..
#
# $$ \dot H = 0 = \frac{d}{dt} (\vec r \wedge \dot r) $$
#
# This "the time derivative is zero" is the definition of a CONSERVED QUANTITY! Man that was easy.

# %% [markdown]
# Now let's move to Kepler's Second Law. (don't think too hard about the order).
#
# So, Kepler's Second Law is about the area swept out at any given moment by an orbiting body. Well, we can represent the motion of an object with the position vector and tis velocity vector, so we can construct a paralellogram $\vec r \wedge \dot r dt$. Of course the actual area swept out is a triangle so we divide thsi by two. Thus:
#
# $$ dA = \frac12 \vec r \wedge \dot r dt $$
# $$ \dot A = \frac12 \vec r \wedge \dot r $$
# $$ \dot A = \frac12 H$$
#
# So a nice result. However we do need to point out that we pulled some weird derivative jujitsu there. Careful when dividing by differentials.
#
# The other point of this result is that since H is conserved, that means the rate of area swept out is constant. Which is Kepler's Second Law. Yay!

# %% [markdown]
# Okay so now let's look at some weird unusual things. First of all, show that $\vec r \cdot \dot r$ is zero. We do this by pulling *out* a time derivative, doing the product rule in reverse.
#
# $$ = \frac12 \frac{d}{dt}(\vec r \cdot \vec r) $$
#
# But wait, a dot product... is a constant. And a constant has a time derivative of zero. Thus, the dot product of a vector with its "velocity" vector is zero. This would appear to be absolutely general. (The video uses unit vectors for this but changing the magnitude will have absolutely no effect on this).
#
# Anyway, that's useful, and so let's use it to figure out more about H.
#
# $$ H = \vec r \wedge \dot r = (r \hat r) \wedge (\dot r \hat r + r \frac{d}{dt} \hat r) $$
#
# I will point out that I would love to put a derivative, hat, and vector on multiple things, but LaTeX wont' let me. So we now have notation confusion abounding. Lovely. Anyway, regardless of all that, what we've done is split the components up into their individual parts, reminding everyone that $\dot r$ as a vector would actually have multiple components and be subject to the product rule. Anyway distribute through the wedge product now--the $\hat r$ terms cancel due to being the same and we are left with
#
# $$ = r\hat r \wedge r \frac{d}{dt} \hat r = r^2 \hat r \wedge \frac{d}{dt} \hat r = r^2 (\hat r \frac{d}{dt} \hat r - \hat r \cdot \frac{d}{dt} \hat r )$$
#
# We previously showed that the dot product goes to nothing. And so...
#
# $$ H = r^2 \hat r \partial_t \hat r $$
#
# Where we introduce the relativistic version of the time derivative operator to keep us all sane. For the record this is the angular momentum per unit mass equation.

# %% [markdown]
# First of all just note that $\hat r \cdot (\dot r \hat r + r \partial_t \hat r) = \dot r \hat r \cdot \hat r = \dot r$. Useful.
#
# Anyway let's return to our vector equation and work with it a bit to find more stuff. We use the above thing in the third line.
#
# $$ \ddot r = \frac{-\mu}{r^2} \hat r $$
# $$ \Rightarrow \ddot r \cdot \dot r = \frac{-\mu}{r^2} \hat r \cdot \dot r $$
# $$ \Rightarrow \frac12 \partial_t (\dot r \cdot \dot r) = \frac{-\mu}{r^2} \dot r $$
# $$ \Rightarrow \frac12 \partial_t (v^2) = \partial_t \frac{\mu}{r} $$
# $$ \Rightarrow \partial_t (\frac12 v^2) = \partial_t \frac{\mu}{r} $$
# $$ \Rightarrow \partial_t (\frac12 v^2 - \frac{\mu}{r}) = 0 $$
#
# More conserved quantities! Always good. This turns out to literally be the Energy E. (Total energy per unit mass, really). It's easily visible as a kinetic energy term and potential energy term. E = T + U. If we're particuarly clever we can also note that this is the Hamiltonian. Thus both energy and angular momentum are conserved!

# %% [markdown]
# # PART VII: Kepler Problem 2
#
# ## Time for magic!
#
# For no particular reason, let's...
#
# $$ H \ddot r = r^2 \hat r \partial_t \hat r \frac{-\mu}{r^2}\hat r $$
# $$ = -\mu \hat r \partial_t \hat r \hat r $$
# $$ = \mu \partial_t \hat r \hat r^2 $$
# $$ = \mu \partial_t \hat r $$
#
# And so...
#
# $$ H\ddot r - \mu \partial_t \hat r = 0 $$
# $$ \partial_t(H\dot r - \mu \hat r) = 0 $$
#
# The derivative can be extracted as both H and $\mu$ are constants. This is a new conservation law.
#
# $$ H\dot r - \mu \hat r = \vec c $$
#
# Note that H is a bivector, so the first term is a rotated vector, and the other is a scaled vector. $\vec c$ is known as the Laplace vector. The curious thing is that the Laplace vector is entirely conserved--it can't even rotate, it must always point the exact same direction. This is knowing full well that the radial direction and velocity direction change.
#
# So, starting with this new mysterious conserved quantity, we start finagling:
#
# $$ H \dot r = \vec c + \mu \hat r $$
# $$ \Rightarrow H \dot r\vec r = \vec c\vec r + \mu \hat r\vec r $$
# $$ \Rightarrow H (\dot r\cdot \vec r + \dot r\wedge \vec r ) = \vec c \cdot \vec r + \vec c \wedge \vec r + \mu \hat r \cdot \vec r $$
# $$ \Rightarrow (\dot r\cdot \vec r)H - H(\vec r\wedge \dot r) = crcos\theta + \vec c \wedge \vec r + \mu r $$
# $$ \Rightarrow (\dot r\cdot \vec r)H -H^2 = crcos\theta + \vec c \wedge \vec r + \mu r $$
#
# At this poitn we note that we have bivector and scalar sections, so we can split this off into two different equations.
#
# $$ (\dot r\cdot \vec r)H = \vec c \wedge \vec r $$
# $$ -H^2 = crcos\theta + \mu r $$
#
# "Wait, $H^2$ is a scalar?" Yes, remember, the bivector squared is -1. Usually this quantity is superceded using $-H^2 = h^2$ to avoid leaving unnatural-looking signs.
#
# $$ h^2 = r(ccos\theta + \mu) $$
# $$ r = \frac{h^2}{\mu + ccos\theta} $$
#
# Neat. Usually though we want to write it this way
#
# $$ r = \frac{h^2/\mu}{1 + (c/\mu)cos\theta} $$
#
# For notational reasons. Usually $p = h^2/\mu$ and $e = c/\mu$, so...
#
# $$ r = \frac{p}{1 + ecos\theta} $$
#
# You might recognize e: it's the eccentricity. p is the semi-latus rectum, though, a bit mysterious.In general though all we're doing is defining a conic section. Which. You know, this is the two body problem, of course it is. Adjust e to create the shape, while p determines the size.
#
# For circular orbits, e is zero and thus c is also zero, which makes sense. c, the Laplace Vector, has to maintain not just magnitude but also direction as it is completely conserved, and for a circular orbit the direction of r changes to all directions but nothing else does, so in order to keep the difference the same the Laplace Vector must be zero. This is not the case for, say eliptical results:
#
# ![image.png](attachment:image.png)
#
# Where the Laplace vector most defintiely can point a particular direction.

# %% [markdown]
# # PART VIII: Kepler Problem 3
#
# https://youtu.be/LhcKldTK9r4?si=kZKhyw6_CZGuTOnK
#
# For the record p in the previous part, the semi-latus rectum (what a werid name) is the distance from the origin to the point the elipse crosses the y axis. Bit odd but it seems to work. Our friend a is $a = p/(1-e^2)$. And at this point this isn't really geometric algebra, it's just deriving more shapes from things. Getting Kepler's Third Law (elipse area exact expression) is easy.
#
# More ways to look at $\vec c$ though:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# So at the moment I don't fully understand WHY we're doing this, but we're going to do some geometric albecraic finnickic (I wanted it to rhyme okay) stuff.
#
# So we have our elipse equation. We want to back it up a bit:
#
# $$ r = \frac{h^2/\mu}{1+ecos\theta} = \frac{h^2/\mu}{1+\vec e \cdot \hat r} $$
#
# Note that we've introduced an "eccentricity vector" here. It's just a vector in the same direction as c with the magnitude of the eccentricity. As the two are related quantities this isn't a huge jump.
#
# $$ \Rightarrow 1 + \vec e \cdot \hat r = \frac{h^2}{\mu r} $$
# $$ \Rightarrow \vec e \cdot \hat r = \frac{h^2}{\mu r} - 1 $$
#
# Let's set that aside and turn to our angular momentum equaiton, throwing $\vec e$ into it as well.
#
# $$ H\partial_t \vec r - \mu \hat r = \vec c = \mu \vec e $$
# $$ \Rightarrow H \partial_t \vec r = \mu(\vec e + \hat r) $$
# $$ \Rightarrow (H \partial_t \vec r)^2 = \mu^2(\vec e + \hat r)^2  $$
#
# Remember that we defined $-H^2 = h^2$. Let's write out in full what we have:
#
# $$ H\partial_t \vec r H \partial_t \vec r $$
#
# Problem is to get $H^2$ here we have to move it through the vector r. The video doesn't do this but I know what we are looking for: THE COMMUTATOR! Aka a description of how exactly the two *don't* commute. We expect a simple minus sign, but these aren't just vectors, H is a bivector. So...
#
# $$ (r_1e_1 + r_2e_2)e_1e_2 = (r_1e_2 - r_2e_1) $$
# $$ e_1e_2(r_1e_1 + r_2e_2) = (-r_1e_2 + r_2e_1) $$
#
# The difference is, as predicted, a minus sign. So when we do a flip...
#
# $$ H\partial_t \vec r H \partial_t \vec r = -HH\partial_t \vec r\partial_t \vec r$$
#
# Fortunately now we have expressions for these and it becomes
#
# $$ = h^2 v^2 $$
#
# Tah-dah! Anyway now we adjust our squaring properly:
#
# $$ \Rightarrow h^2 v^2 = \mu^2(\vec e^2 + \vec e \hat r+ \hat r \vec e+ \hat r^2)  $$
# $$ \Rightarrow h^2 v^2 = \mu^2(e^2 + \vec e \hat r+ \hat r \vec e+ 1)  $$
# $$ \Rightarrow h^2 v^2 = \mu^2(e^2 + 2\vec e \cdot \hat r+ 1)  $$
#
# And we put in our substitution from earlier in.
#
# $$ \Rightarrow h^2 v^2 = \mu^2(e^2 + 2h^2 \frac{1}{\mu r} -1)  $$
# $$ \Rightarrow h^2 v^2 = \mu^2e^2 + 2h^2 \frac{\mu}{r} -\mu^2  $$
# $$ \Rightarrow h^2 v^2 - 2h^2 \frac{\mu}{r} = \mu^2(e^2-1)  $$
# $$ \Rightarrow v^2 - 2 \frac{\mu}{r} = \frac{\mu^2}{h^2}(e^2-1)  $$
#
# Wait a second, the left-hand side? that's the energy! Well, twice the energy anyway.
#
# $$ \Rightarrow 2E = \frac{\mu^2}{h^2}(e^2-1)  $$
# $$ \Rightarrow E = \frac{-\mu^2}{2h^2}(1-e^2)  $$
#
# Now it makes sense why we were trying to get this, more expressions for the energy are always good. The question is what exactly does this mean? Well it helps us classify energy based on orbit type, but we already know that. (Parabolic orbits have zero energy). You can also espress it as p using $p = h^2/\mu$
#
# $$ E = \frac{-\mu}{2p}(1-e^2) $$
#
# Alternatively
#
# $$ E = \frac{-\mu}{2a} $$
#
# Which. Y'know. Is probably the preferred one.
#
# There are other things we can derive but it doesn't particuarly rely on geometric algebra.
#
# Now... ONTO THE THIRD DIMENSION.

# %% [markdown]
# # PART IX: Geometric Algebra in 3D - Fundamentals
#
# https://youtu.be/ElLl6gzNbFE?si=-0NfLUjXhnJ9Gem8
#
# LE BIG ONE TIME!
#
# Let's build this up like so:
#
# We naturally have a scalar.
#
# We have three vectors in 3D, $e_1 e_2 e_3$, which are the same as xyz but again we won't be doing that directly.
#
# Now we don't just have one bivector, we have three, made from all combinations of unit vectors. They are $e_1e_2, e_2e_3, e_3e_1$. Note that the order is maintained, 123123123, so 31 is still in the same order. Circulation matters.
#
# Now we have a trivector, $e_1e_2e_3$. Since unit vector dot products are zero, this is equivalent to $e_1\wedge e_2 \wedge e_3$.
#
# Other rules still hold: unit vectors square to 1, bivectors square to -1. But what of the trivector?
#
# $$ e_1e_2e_3e_1e_2e_3 = e_1e_2e_3e_3e_1e_2 = e_1e_2e_1e_2 = -1$$
#
# Last step is because it reduced to a square of a bivector. This is a curious product. Anyway the multivector is of the form
#
# $$ (1,e_1,e_2,e_3,e_1e_2,e_2e_3,e_3e_1,e_1e_2e_3) $$
#
# Anyway, what IS a Trivector? Well, we can think of it as extending a bivector into a volume. In the case of unit vectors, this is best seen as a cube.
#
# ![image-2.png](attachment:image-2.png)
#
# A curious result is the order of the three.
#
# $$ e_1e_2e_3 = e_2e_3e_1 = e_3e_1e_2 $$
# $$ e_3e_2e_1 = e_2e_1e_3 = e_1e_3e_2 $$
#
# This should be familiar, this is how one of those funky "delta" functions work. (The kroniker delta is 2D and I forget the name of the 3D one... regardless, it still shows the behavior). There is one behavior that is different: the "Delta" says that if two indices match, the result is 0. But if two indices match in this setup, then we simply don't have a *trivector* anymore, we end up with a vector--aka we go elsewhere in the geometric space. Interesting!
#
# Ascneding is generally considered "positive" and descending is generally considered "negative."
#
# A note on circulation direciton in volumes: nothing agrees, basically. You can imagine it as circulations appearinmg on each surface, based on the bivectors that make up the situation, all three of the 12 23 31 circulations don't agree on boundaries. However, visualizing six divverent vortices can get tiresome, even if their orientations can be deduced based on the simple rule of "nothing agrees at any boundary." Let me see if there's maybe a better way to think of it... (Well, besides "positive and negative" volume)
#
# Aha! Found it! When flattening the cube out like a die, I noted that every circulation *was the same relative direction*. Which means rather than thinking about relations, we can use a single relation: the orientation compared with the center of the cube. Imagine a pole sticking out of each cube face going toward the center of the cube. Circulations going counterclockwise treating that pole as "up" are positive, but clockwise are negative. A trivector should have all faces circulated clockwise or coutnerclockwise with respect to the central pointing pole. This is a concept similar in idea and scope to the normal vector--in fact it can be represented by the negative normal vector if we wanted.
#
# With this in mind drawing a single circulation on a trivector cube should be sufficient to describe it.
#
# For the record the center of a trivector cube is not the origin, that's one of the vertexes, as it was composed out of the unit vectors. Also keep in mind that this is just a visualization tool. There are alternatives. There is a sense in which there is a "Flow" around the tips of the original vectors from 1 to 2 to 3. The only reason this isn't as nice as the other one is because the other half of the cube flows along the same path in the opposite direction. But you can still superimpose a triangle in your cube for visualization if you wish: in this case circulation occurs around the line leaving the origin, counterclockwise positive, clockwise negative.
#
# Fun fact: it is not possible to create a cube where all flows "agree" at boundaries, so presumably that is why this notation was chosen as standard.
#
# In 3D geometric algebra, trivectors are the Pseudoscalars. Sometimes the bivectors are called pseudovectors, or axial vectors. Sometimes vectors are called "polar vectors". We'll be trying to be unambiguous with our notation, specifically saying trivector.

# %% [markdown]
# # PART X: The Vector-Bivector Product 1
#
# https://youtu.be/njxg5nUwZKA?si=Ca3cQbYB_lDPuKpr
#
# Now let's see about multiplications of things!
#
# Start with a vector $a = e_1 + e_2 + e_3$. In multivector language we would say (0,1,1,1,0,0,0,0).
#
# What happens iwe we multiply by $e_1e_2$? Well...
#
# $$ e_1e_1e_2 + e_2e_1e_2 + e_3e_1e_2 = e_2 - e_1 + e_1e_2e_3$$
#
# So we have two vector components and a trivector component. (We set it to 123 to make it clear that it was the positive one). We can separate these parts out by noting weriting $\langle aB \rangle_x$, where x is the grade of the parts. so the grade-1 part is $e_2 - e_1$ and the grade-3 part is $e_1e_2e_3$.
#
# Let's notice a pattern. A vector times a vector produced a scalar and a bivector, or <1><1> -> <0> + <2>. Now a vector and a bivector went like <1><2> -> <1> + <3>. Curious. There appears to be a pattern here, but what is it?
#
# Note that this holds for applying the bivector on teh left as well, just with a sign flip on the vector part. We can state thsi property as:
#
# $$ aB = <aB>_1 + <aB>_3 $$
# $$ <aB>_1 = -<Ba>_1 $$
# $$ <aB>_3 = <Ba>_3 $$
#
# These are true in general but we did only show it for a specific case--as if we did it in general we would end up with a constant pileup. Which is annoying.
#
# By solving this as a system of equations we can get the following relations:
#
# $$ <aB>_1 = \frac12 (aB-Ba) = a \cdot B$$
# $$ <aB>_3 = \frac12 (aB+Ba) = a \wedge B$$
#
# Note that we have defined the operations of dot and wedge products for these now! This seems odd, yes, but note that these relations *do* scale, as the geometric product definitions are simialr to before, just with a second vector replaced with a bivector, and the SIGN CHANGE. The dot product is anticommutative here, whilet he wedge product is commutative.
#
# A good note is that in general the dot product is a grade lowerer, and the wedge product is a grade increaser (hence the wedge pointing UP). I look forward to the full generalization of this. But that's for the NEXT PART~!

# %% [markdown]
# # PART XI: The Vector-Bivector Product 2
#
# https://youtu.be/RbKjaPDoGlw?si=tlKQp45sIAnF3dDX
#
# So, what are some cases for the vector-bivector product?
#
# If a vector is in the plane of the bivector, the result is a single vector, and a single vector that anticommutes at that. Thus, the in-plane (or one might think "paralell" component) is the dot product. Note that agian the dot product for two vectors does not anticommute, thus funky difference is present.
#
# Video spent a long time showing this... it seems obvious to me that it just follows. I suppose rigorous proof is special.
#
# Now what of the PERPENDICULAR component, that is, a avector pointing right out of the plane. This obviously becomes the trivector, we kind of already defined this. This one is commutative, unlike the 2D case where this is anticommutative.
#
# Again the proof doesnt' seem exactly interesting, it's a matter of just converting everythign into... actually might as well wright it down in one case, the dot product form is similar.
#
# $$ w(u\wedge v) = w\frac12 (uv-vu) = \frac12 (wuv - wvu) = \frac12 (uvw - vuw) = \frac12(uv-vu)w = (u \wedge v) w $$
#
# Note that we moved w through the vectors. But all vectors are orthogonal in this case, so the orthogonality just means that a sign gets flipped when it's shuffled. But w moves twice each time, so the sign flip does not occur. Tah-dah. The dot product introduces a sign change because... okay fine we'll jsut demonstrate.
#
# $$ u(u \wedge v) = u \frac12 (uv-vu) = \frac12 (u^2v - uvu) = \frac12 (vu^2 - uvu) = \frac12 (vu-uv) u = (v \wedge u)u = -(u \wedge v) u $$
#
# What happened here is that u, being in the plane, is one of the components of the bivector, so u=u. There's no orthogonality flipping occuring, but there is squaring, and squaring becomes a scalar that can just be moved. And as u is already part of the sandwich in the second term it can just be peeled off. Tah-dah!
#
# So paralell (dot product) anticommutes, but perpendicular (wedge product) commutes. Another way to show this...
#
# $$ a \cdot B = a_{||} \cdot B = a_{||} B$$
#
# $$ a \wedge B = a_{\perp} \wedge B = a_{\perp} B $$
#
# GEOMETRICAL INTERPRETATION: aB is a recuction of the bivector B into a vector. Or it can be thought of B rotating the vector a and scaling it, which makes sense as B can also be thought of as a circulation.
#
# ![image.png](attachment:image.png)
#
# Note that the trivector does not appear in this image. It would be annoying to draw. Notably it wouldn't be a cube, it'd be a rectangular prism as the length of the vector involved is no longer 1 and the bivector itself isn't square. (In fact we can argue that the bivector here is a paralellogram, but it'd still be extended into a prism.
#
# Great now I have to wonder if we can imagine the trivector part as a prism or a full paralellopiped. TIME TO DO SOME CUSTOM MATH!

# %% [markdown]
# Okay so this turns out to be simpler than I thought. A paralellogram prism and a parallelepiped is the same: bese area times height. Or, in short, tilting the object does not actually change its volume, so we are free to imagine the trivector as a parallelepiped and still retain everything. This naturally means the three-vector wedge product can create trivectors as well as a bivector and a vector.
#
# Funny thing though is that trivectors are considered the same if their volume is the same, so the visual shape we have in mind is almost irrelevant. It can be a cube, it can be a parallelepiped, or anything. Whichever communicates clearly what is happening is probably the best.

# %% [markdown]
# # PART XII: Bivector Addition
#
# https://youtu.be/BcJGgG4HmwE?si=yDWjzzMhXjLV9b69
#
# The primary result is obvious: if you have two bivectors in 3D, you add the components together in terms of the basis bivectors. But what is the GEOMETRIC interpretation?
#
# Ah a reminder that bivectors have no particular shape, as we talked about trivectors above, ehe... look at me, jumping ahead. Ultimately adding bivectors together is a combination of the areas. Paralellograms and squares are generally the most convenient though. In 2D space you just slap them together, making a tesselation. Or Perhaps you decompose the bivectors into the vectors that compose them and work from there.
#
# In 3D we can do a thing similarly to how we do vectors. Two bivectors will "fold" into the center...
#
# ![image-2.png](attachment:image-2.png)
#
# You can laso use a tip-to-tail method in 3D as well, effectively making two bivectors the parts of a ramp, the ramp itself being the sum.
#
# The thing is in 3D you may have initially two bivectors that are not the same size and can't just be "added" visually. But remember, the 2x6 bivector is the same as the 4x3 bivector, so it can always be scaled to a different size for this visualization. This is similar to moving vectors away from the origin even though no vectors ever do that.
#
# When adding we can also consider the vectors that make it up. For instance in the above image, we can add $e_1 + e_2$ first, and then project along $e_3$ to get the additive bivector. This is particuarly helpful when you, say, have theree or more bivectors being added: add two but find out what the vectors are that define them, and then use the two shared vectors to figure out where things go. Is it a bit of a mess? Yes, but it can be visualized, and there are multiple ways to do it.
#
# One of the best ways is to just "do what the math tells you" For instance, let's add these bivectors:
#
# $$ -e_3e_1, e_2e_3, e_1e_2 $$
#
# Which are just the unit bivectors, except one has inverted circulation/area. A better way to write it might be $e_1e_3$.
#
# The sum $e_1e_3 + e_2e_3$ can be written $(e_1+e_2)e_3$. (Keep in mind this is only due to unit vector orthogonality). WHich means this addition can be composed of the vector $e_1+e_2$ and the vector $e_3$. Yay! Just visualize the paralellogram projected from these vectors, viola.
#
# If we add the third one we have $(e_1+e_2)e_3 + e_1e_2$. We can force this to match as well, but unfortunately the obvious way doesn't quite work, as trying to force a (e_1+e_2) to exist gives us a loose value of 1.
#
# However, currently as we only have orthogonal unit vectors, we can consider everything a wedge product.
#
# $$(e_1+e_2)\wedge e_3 + e_1\wedge e_2$$.
#
# This is the same as all individual bivectors ARE wedges of vectors. Now, the fun part is that vectors wedging with themselves become zero, which means we are free to do this
#
# $$=(e_1+e_2)\wedge e_3 + (e_1+e_2)\wedge e_2$$.
#
# Which we can *reverse* distribute.
#
# $$=(e_1+e_2)\wedge (e_3+e_2) $$.
#
# And now we have ourselves two vectors that will create a bivector that we desire. Notably we can't drop the $\wedge$ as now all components aren't orthogonal, but we can still imagine the shape this would take as we have two vectors that trace out a paralellogram! This can also be thought of as a deformation of one of the bivectors to go "match."
#
# Evidentially once you go to 4D it's possible to make bivectors that are *not* decomposable into two vectors. I am interested to see what exactly this would be, but hmm.

# %% [markdown]
# EXERCISE: show the following bivectors to be the composition of two wedged vectors.
#
# $$ B_1 = 2e_1e_2 - e_3e_1 $$
# $$ B_2 = e_2e_3 $$
# $$ B_1 + B_2 = 2e_1e_2 + e_2e_3 - e_3e_1 $$
#
# $B_2$ is trivially $e_2 \wedge e_3$.
#
# for $B_1$...
#
# $$ -2e_2e_1 - e_3e_1 = -(2e_2 + e_3)e_1 = -2e_2 -e_3 \wedge e_1$$
#
# Note that we could put the sign on either side of the wedge and it would not change, there is no simple "different" in this case.
#
# $$ -2e_2 -e_3 \wedge e_1 + e_2 \wedge e_3 $$
#
# Now here's something interesting. While we can in fact add the $e_3$, we have the wrong scale...
#
# $$ -2e_2 -e_3 \wedge e_1 + (e_2 - e_3) \wedge e_3 $$
#
# However, remember that bivectors can be scaled by their area. So if we need to add a -2 to $e_2$, that means we need to scale the other side by $-1/2$. Like so...
#
# $$ -2e_2 -e_3 \wedge e_1 + (-2e_2 - e_3) \wedge \frac{-1}{2}e_3 $$
#
# Note that we don't need to change the $e_3$ term as it is just a zero. Anyway, we reverse distribute...
#
# $$ (-2e_2 - e_3) \wedge (e_1 - \frac12 e_3) $$
#
# And this should be the decomposition of our sum bivector!

# %% [markdown]
# We can talk about torque now. Torque can be simply represented by a bivector. The lever arm is r, the force is F. So $\tau = r \wedge F$. Note that the circulation goes in the direction of circular motion.
#
# The great thing is that now we can just ADD TORQUES IN DIFFERENT PLANES OF MOTION
#
# There's no need to even write anything it just works.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # PART XIII: 3D Rotations and Rotors
#
# Let's start SPINNING THINGS!
#
# Reflection in 2D: $u' = v^{-1} u v$
#
# Also if a vector is a unit vector it is its own inverse. So if we restrict to unit vectors, we then use vuv to reflect. wvuvw is a double reflection, but it can also be a single reflection. And can be used to derive the rotation in two dimensions by an arbitrary angle.
#
# $$ e^{-\theta e_1e_2}ue^{\theta e_1e_2} $$
#
# This will rotate by double $\theta$ so if we want to rotate by exactly $\theta$ we should probably make it explicit and
#
# $$ e^{-\frac12\theta e_1e_2}ue^{\frac12\theta e_1e_2} $$
#
# This is 2D. Let's now apply this to 3D. The claim is that if two vectors v and w are unit vectors, then the expression wvuvw rotates u around the normal to the plane vw, where the angle between v and w is $\theta/2$, while $\theta$ is the actual angle of rotation. u need not be in the same plane in this case.
#
# So to argue this, first of all it obviously works for the component of u projected onto the plane, that is, $u_{||}$ as it is, in fact, in the plane with them and thus has the exact same math as in the 2D case. The perpendicular par tis nto changed by the reflection as it's flipped across the plane and then back, unaltered. (Again, so long as our vectors are unit vectors for vw). So yeah wvuvw works.
#
# Note that we didn't really bring in an axis to do this. Now it *does* rotate around the axis normal to the plane, but in higher dimensions this wouldn't work, this is more general. The power of everything is that if we use a bivector to define the plane we also describe the circulation direciton. Nice! Select two unit vectors for rotating, one being a basis vector, the other being selected to scale the angle. (remember to normalize!) example: $e_1$ and we want to rotate by 90 degrees, so we set the other unit vector to $\frac{1}{\sqrt2}(e_1+e_2)$, aka the 45 degree unit vector. Tah-dah.
#
# We note that we can make this arbitrary. Rotaiton in any of the unit basis bivectors is easy. But... what of rottaion in another plane? Well we can define a "length" of a multi-component bivector. Fortunatley it's very simple:
#
# $$ B = ae_1e_2 + be_2e_3 + ce_3e_1 $$
# $$ |B|^2 = a^2+b^2+c^2 $$
#
# Aka exactly the same as vectors. If the magnitude (and thus magntiude squared) is 1, it'll work for a rotation.
#
# So in general we write wvuvw, but we can now consider single objects, Rotors. So we rewirte this as $RuR^\dagger$, where the $\dagger$ is the inverse. (It is also reminiscent of Hermitian conjugates and the like). $R^{\dagger\dagger}= R$ by the way.
#
# $$ R^\dagger = vw $$
# $$ = v\cdot w + v \wedge w $$
# $$ = |v||w|cos\theta/2 + |v||w|sin\theta/2 B $$
#
# B is whatever bivector that describes the plane we are rotating in. We happen to know that the constants out front do not matter as during a rotation they will be canceled out, so we are free to normalize them out.
#
# $$ = cos\theta/2 + sin\theta/2 B $$
# $$ = e^{\theta/2 B}$$
# $$ R = e^{-\theta/2 B} = cos\theta/2 - sin\theta/2 B$$
#
# Which is what we expected. Rotors are multivectors with a scalar and bivector component. We state the general rotaiton formula as:
#
# $$ u' = e^{-\frac12\theta B}ue^{\frac12\theta B} $$
#
# With the requirement that B is a unit bivector. This is in 3D space, for the record. Note that if for some reason yo uhave a bivector that doesn't square to -1, then this probably won't work. But in 3D space you shouldn't have this issue. (When you start dealing with relativity be careful).

# %% [markdown]
# Composite rotations are simple, as we can combine rotors.
#
# $$ R_2R_1uR_1^\dagger R_2^\dagger = (R_2R_1)u(R_1R_2)^\dagger$$
#
# This should be kind of obvious as the exponentials will combine on either side and the signs will be opposite but magnitudes will be equal. So yeah.
#
# $$ e^{-\frac12 \theta_1 B_1 - \frac12 \theta_2 B_2} u e^{\frac12 \theta_1 B_1 + \frac12 \theta_2 B_2} $$
#
# Since each sum of bivectors is another bivector, that means there is a single bivector with a single constant in front of it, so we can always rework this into a single rotor. Tah-dah!
#
# Bizarre property: $RuR^\dagger = (-R)u(-R^\dagger)$. Which basically states abstractly that you can rotate backwards to get the same result if you want. Mathematically this basically states that you always have two rotor sets that can do one rotation, they are not unique.
#
# Very unusual property about rotors. If you apply a rotor TO a rotor, you get another rotor. But the rotation that should cause no change *doesn't*. Take, for instance, $R_1uR_1^\dagger$. Let's rotate this again by $R_2$, where $R_2$ *specifically* is the rotation of a full circle, $2\pi$. This means $R_2 = e^{\pi B}$. However, when you alter an exponential by the angle $\pi$, you don't fully rotat it, you flip its sign. Thus,
#
# $$ R_2R_1uR_1^\dagger R_2^\dagger = (-R_1) u (-R_1^\dagger) $$
#
# So the final result is still the same, but the rotors themselves flip sign when rotated a full circle. It takes $4\pi$ to get them back to where they started. This seems unusual and esoteric and just a weirdness of the calculation that goes away when you carry it out. If that was all it was I wouldn't be writing it down, because there's quantum spin weirdness that actually needs to rotate twice to return to where it was. It can actually be used to model things. They are called SPINORS. (both in physics and as well as pure math as an object that has to spin twice to return to its origin).

# %% [markdown]
# # PART XIV: Linear and Spherical Interpolation
#
# https://youtu.be/ibkT5ao8kGY?si=_hfXk8JrCGJYsMjO

# %% [markdown]
# So a new application arises. Interpolation.
#
# So interpolation is a bit like this: take two vectors. Draw a line between their two tips. We want a vector that points somewhere along that line, the "Somewhere" defined by a quantity s that scales from 0 to 1.
#
# ![image.png](attachment:image.png)
#
# $$ v_s = v_i + s(v_f-v_i) = (1-s)v_i + sv_f$$
#
# Rather simple really.

# %% [markdown]
# Now let's move to Spherical Interpolation. A.K.A. SLERP. I love silly acronyms.
#
# ![image.png](attachment:image.png)
#
# The main things of interest here are that we're not interpolating over a line, we're interpolating over an arc. Specifically this arc has MANY great properties: it's part of a great circle, it's the shortest path between the two points of the vectors (well if the vectors really are on the unit sphere as they shoudl be), it's also directly in line with the bivector plane created by the two vectors, it's just full of great stuff. This means that the spherical interpolations are *rotations*.
#
# Which leads to the somewhat obvious thought of "well in that case let's just use the rotors to do it." We'll see if that's where the video goes.
#
# Turns out that yes we can do it. Since the rotation is in a 2D sense we can just do it with one side, but in general we want to use a rotor sandwich. Just scale the angle and make sure we know the plane B, BUT since we are on the unit sphere in the first place we already have two vectors that can be used to defien B. Just make sure we have a full definition. Just replace all $\theta$ by $s\theta$. Tah-dah.
#
# Also can be represented as $R^s$. s only goes from 0 to 1, and the exponential absorbs powers as products in the power $(e^x)^s = e^{sx}$, easy.
#
# Now, what if we want a direct formula? Well, that's a little different.
#
# $$ v_s = av_i + bv_f $$
#
# We seek expressions for a and b. Using the single-rotor notation (which we can do in 2D situations) we simplify it greatly.
#
# $$ \Rightarrow v_i R^s = av_i + bv_iR $$
# $$ \Rightarrow v_i R^s \wedge v_iR = (av_i + bv_iR)\wedge v_iR $$
# $$ \Rightarrow \frac12(v_iR^sv_iR - v_iRv_iR^s) = \frac12 a(v_i^2R - v_i R v_i)$$
#
# Note that the b-term vanished here as we wedged the vector with itself.
#
# $$ \Rightarrow v_i^2R^{s\dagger}R - v_i^2R^\dagger R^s = a(v_i^2R - v_i^2 R^\dagger)$$
# $$ \Rightarrow R^{s\dagger}R - R^\dagger R^s = a(R - R^\dagger)$$
#
# The unit vectors are gone as they all squared, and now we have just a bunch of rotors.
#
# $$ \Rightarrow R^{s\dagger}R - (R^{s\dagger}R)^\dagger = a(R - R^\dagger)$$
#
# A rotor minus its conjugate and a rotor minus its inverse on both sides, scaled by a constant. Curious. A property of this type of inverse, the conjugate, is that the "imaginary" component is all that remains when you subtract the two--in this case it would be only the bivector component that remains.
#
# $$ \Rightarrow 2 sin(\theta(1-s)) B = 2 a sin\theta B$$
# $$ \Rightarrow sin(\theta(1-s)) = a sin\theta$$
# $$ \Rightarrow \frac{sin(\theta(1-s))}{sin\theta} = a$$
#
# Which is a closed expression for a. Note that we could have gotten to this via imaginary numbers... but that would be rather artificial, here it just arises from the geometric algebra.
#
# Similar arguments exist for getting b.
#
# $$ b = \frac{sin(s\theta)}{sin\theta} $$
#
# So we have
#
# $$ v_s = \frac{sin(\theta(1-s))}{sin\theta}v_i + \frac{sin(s\theta)}{sin\theta}v_f $$
#
# As the complete solution. While this may have looked complicated, how would you have gone about doing this without geometric algebra rotations? Rotations without geometric algebra is quite a pain, remember, and introducing imaginary numbers is a big of a leap.
#
# There is one thought. How *do* you find the angle between two vectors?
#
# $$ \theta = arccos(v_i \cdot v_f) $$
#
# This *should* be simple if you have the compositions of the angles.
#
# In the small angle approximation:
#
# $$ v_s = (1-s)v_i + sv_f $$
#
# We recover linear interpolation.
#
# ((By the way the dagger operator is "reverse the order" operation, so ab -> ba or abc -> cba)).

# %% [markdown]
# Final topic: NORMALIZED linear interpolation!
#
# WHich is to say you take the linear interpolation and normalize the result. Not required for SLERP since the unit sphere is automatically considered to be present. Gotta say, not much special about this, but do note that it won't produce the same result as SLERP since angles may not match up with linear scaling.
#
# Why do we care? Probably application dependent.

# %% [markdown]
# # Part XV: Rotors and Quaternions
#
# I think we're now in the "bonus content" areas of this all. Neat. *Neat...*
#
# https://youtu.be/nJnWM7R6Y5A?si=EmjlXkd0Zp2uwu-y
#
# Also we have a theme song now.
#
# One thing we can do in a Geometric Algebra system is divide things by grade. For instance, since vector products produce grade-0 (scalars) and grade-2 (bivectors), we can consider just the even subalgebra space, so we only consider $(1,e_1e_2,e_2e_3,e_3e_1)$, in essence. This is how we write Rotors, for instance.
#
# Property: this subalbegra is closed, so no matter what exists we end up where we started. Note that while we are closed here, if we were in 4D you could multiply bivectors to get a 4-vector. But 4-vectors don't exist here so we aren't concerned.
#
# In this subalbegra, we note the squares: $1, -1, -1, -1$. This is looking like the quaternions and it actually is! It maps directly to (1,i,j,-k). Note that we have a weird added minus sign, this is due to the fact that the "k" in the quaternions is actually made by $e_3e_1$ not $e_1e_3$.
#
# $$ a+be_1e_2 + ce_2e_3 + de_3e_1 <--> a+bi+cj-dk $$
#
# The isomorphism is complete. (Ah so my abstract algebra class actually does have a use).
#
# So we can map rotors to quaternions. This section can basically say "rotors ARE quaternions". The nice thing about the geometric algebra version, the multiplications are inherent. For instance in quaternions if we wnat to do: ki we just have to memorize it. But if we use bivectors, we translate to $e_1e_3e_1e_2 = -e_3e_1e_1e_2 = -e_3e_2 = e_2e_3$. Which is j. so ki=j. Quaternions are BIIIIVECTORS.
#
# Honestly mostly useful if you need to use quaternions for something.
#
# $$ R^\dagger R = RR^\dagger = 1 $$

# %% [markdown]
# # PART XVI: Duality and the Cross Product
#
# Ah, the mysterious Cross Product arrives at last...
#
# https://youtu.be/RAcyVrMNV5s?si=ESyGpq9Ar6OuXE4a
#
# The pesudoscalar commutes with everything. Hence why it's called the pseudoscalar.
#
# Let's see what the pseudoscalar does... Let's refer to it by I for a while.
#
# $$ e_1 I = e_1e_1e_2e_3 = e_2e_3 $$
# $$ e_2 I = e_3e_1 $$
# $$ e_3 I = e_1e_2 $$
#
# Hmm those are the unit bivectors. Neat. In essence I maps the vector to the bivector it is normal to, and it follows the right hand rule for circulation. We can say this makes the vectors and bivectors "Dual" to each other. I is a duality transformation here. And in 3D we can go between vectors and bivectors directly.
#
# In 3D, we have the situation where something of grade r when acted upon by I becomes 3-r. so scalars->pseudoscalar, vectors->bivectors in 3D. In other dimensions this still applies apparently, though it does mean bivectors would map to themselves.
#
# Actually let's try that to see if we understand.
#
# In 4D: $e_1e_2I = e_1e_2e_1e_2e_3e_4 = -e_3e_4$
#
# Well would you look at that.
#
# You can go from bivectors to vectosr as well using $I^{-1}$. This is just the negative pseudoscalar, so we'll probably write it as -I most of the time. THis allows us to do some funky transformaitons.
#
# $$ B = ae_1e_2 + be_2e_3 + ce_3e_1 = ae_3I + be_1I + ce_2I = (be_1 + ce_2 + ae_3)I $$
#
# Which means basically B = vI, so we can represent all bivectors with a vector and the pseudoscalar. In this situation, we say B is dual to v. Note that $|B| = |v|$. This is highly interesting, as we're measuring an area and a length and saying they are equal. Very interesting!
#
# The thing is we can use this to TAKE THE CROSS PRODUCT. The cross product is asking specifically for the "orthogonal vector to a bivector with a length that corresponds to the area of the bivector. IN SPECIFICS:
#
# $$ (a \times b) = (a \wedge b) (-I) $$
#
# Which is to say when you are taking the cross product *you are finding the dual of the bivector your two vectors make*. Note that the cross product is only sensible in 3D.
#
# Proof that it is the same:
#
# $$ (a \wedge b) (-I) $$
# $$ = ((a_1e_1 + a_2e_2 + a_3e_3)\wedge(b_1e_1 + b_2e_3 + b_3e_3)) (-I) $$
# $$ = ((a_1b_2-a_2b_1)e_1e_2+(a_2b_3-a_3b_2)e_2e_3+(a_3b_1-a_1b_3)e_3e_1) (-I) $$
# $$ = (a_1b_2-a_2b_1)e_3+(a_2b_3-a_3b_2)e_1+(a_3b_1-a_1b_3)e_2  $$
#
# That certainly looks like the cross product to me.

# %% [markdown]
# Anyway, this tells us properties of the cross product.
#
# Self crossing is zero.
#
# Crossing with vectors in the same direction is zero.
#
# Cross product anti commutes.
#
# Another benefit of Duals: if you find it annoying to draw bivectors, good news, you can add the dual vectors to get the dual bivector easily.
#
# You can use the dual on rotors to prove that thinking about rotating in a plane and rotating about an axis are identical. Again, just in 3D. As duality between vectors and bivectors is broken in higher dimensions, you can see how rotating around an axis may not make sense in higher dimensions.
#
# We can rewrite the geometric product.
#
# $$ uv = u\cdot v + u \wedge v = u \cdot v + (u \times v) I$$
#
# This is mostly helpful for mapping, and also thinking of things in complex/quaternion space.
#
# When using the geometric product on vectors and bivectors, well, we can send the bivector to the dual vector if we want.
#
# $$ uB = uvI = (u\cdot v)I + (u\wedge v) I $$
#
# If this is easier to think about. It lets us create
#
# $$ u \cdot B = v \times u $$
#
# Where v is the dual vector to B.
#
# The scalar triple product $u \cdot v \times w$ is much easier to think of as a pseudoscalar $u \wedge v \wedge w$. Tah-dah!
#
# In short, dual relations allow GREAT simplifications if used right, and can be used to ease visualizaiton if needed. But it can also overcomplicate things and take things away from their simplicity.

# %% [markdown]
# Jacobi Identity! PROVE IT!
#
# $$ a \times (b \times c) + b \times (c \times a) + c \times (a \times b) = 0 $$
#
# using
#
# $$ w \times (u \times v) = (w \cdot v) u - (w \cdot u) v $$
#
# ...This might be trivial, let's see what happens when we write it out.
#
# $$ (a\cdot c)b - (a\cdot b)c + (b\cdot c)a - (b\cdot a)c + (c\cdot a)b - (c\cdot b)a  $$
#
# As dot products commute every term cancels. So uh. Yeah it is trivial.

# %% [markdown]
# # PART XVII: Linar Transformations, Outermorphism, and the Determinant
#
# https://youtu.be/nyMSrDHLgxQ?si=NJHqHmkzWtjiAXQ1
#
# A transformation maps one vector to another.
#
# A linear transformation is when the mapping, f, is f(x+y) = f(x)+f(y) and f(ax) = af(x). That's it.
#
# Rotations are a linear transformation. So is projection. Geometric algebra can help you *prove* this but I'll be honest, it's basically obvious and I'm interested in geometric albegra in physics application rather than mathematical proofs.
#
# For linear transformations fg is not necessarily equal to gf.
#
# How do we extend linear transformations beyond vectors and to the other objects?
#
# $$f(u\wedge v) = f(u) \wedge f(v) $$
#
# This definition retains the mapping--a bivector is mapped to a bivector. This we can also use on the trivector in the same way. Addition and scalar multiplication are still retained. This is called an "outermorphism" as it extends the definition to act beyond what it was originally set ot act on.
#
# Remember that scalars don't distribute:
#
# $$ f(a (u \wedge v \wedge w)) = af(u)\wedge f(v) \wedge f(w) = a(f(u)\wedge f(v) \wedge f(w)) $$
#
# An interesting property for a lienar transformation on a trivector is, as there is only one type of trivector in 3D space, the result will be just a scalar multiple.
#
# $$ \lambda = \frac{f(e_1e_2e_3)}{e_1e_2e_3} = det(f) $$
#
# THIS VALUE $\lambda$ IS THE DETERMINANT (whaaaaaat).
#
# $$ f(I) = det(f)I $$
#
# Now we can get some properties!

# %% [markdown]
# $$ det(fg) = (fg)(I)(-I) = f(g(I))(-I) = f(det(g)I) (-I) = det(g)f(I)(-I) = det(g)det(f) $$
#
# Nice!
#
# $$ det(ff^{-1}) = det(f)det(f^{-1}) $$
# $$ det(ff^{-1}) = det(identity) $$
#
# Note that we jsut wrote out "identity" instead of I since we're using I for the pseudoscalar. Also keep in mind that this applies to any dimensionality, not just 3D. Linear transformations can be represented by a matrix, but they do nothave to be.
#
# Anyway the determinant of the identity is 1 no mattet the dimensionality. We know this from matrix algebra, but we can also note that it's the *idnetity transformation* so identity(I)=I, which indicates determinant of 1.
#
# $$ \Rightarrow det(f^{-1}) = \frac{1}{det(f)} $$
#
# Which is a known linear algebra thing.
#
# Example: determinant of a rotation!
#
# $$det(R) = R(I)(-I) = \mathcal R I \mathcal R^\dagger (-I) = \mathcal R \mathcal R^\dagger I (-I) = 1$$
#
# Rotational determinants are always 1.
#
# Determinant of a projection!
#
# $$ detP = P(I)(-I) = [P(e_1) \wedge P(e_2) \wedge P(e_3)](-I) $$
#
# Projection operator takes all vectors into a single vector. That means all components of this wedge are in the same line, and thus the wedges to to zero. Thus, detP=0. For ALL projections. (well 2D or higher).
#
# THIS is SUPREMELY USEFUL and I want to try it out. BEHOLD THE DETERMINANT!

# %% [markdown]
# # PART XVIII: The Matrix Representation of a Linear Transformation
#
# https://youtu.be/dOgSuPVlMoI?si=J2H0L5OAkftU-YKb
#
# This appears to be the final boss, as no other videos on Geometric Algebra exist that I can find by this guy. But this is gonna make a major point: MATRICES have arrived. Linear algebra is the study of linear transformations, matrices are just what we use to hold them.
#
# It is sufficient to characterize a linear transformation based on how it interacts with the basis vectors. Which means. Y'know. Is a matrix, as when we apply a matrix to a basis vector we just read off a row. Each column is for a single basis vector.
#
# Most of this video appears to be linear algebra and formally defining the matrix. Interesting and all, but so far not exactly of interest for Geometric Algebra.
#
# Determinant is preserved across linear transformations *of* linear transformations. So a rotation matrix is always det=1 regardless of basis vectors. The trace (sum of diagonals) is also invariant, though that's a bit more unusual.
#
# Hmm for such a long video there wasn't much. Alas.

# %% [markdown]
# # RETURN TO WHERE WE STARTED
#
# ## A Swift Introduciton to Geometric Algebra
#
# ### Reviewed now that we know more.
#
# https://youtu.be/60z_hpEAtD8?si=PtM9VJtkec-OXKvG
#
# Scalars, vectors, bivectors, trivectors, etc.
#
# **DOT/INNER PRODUCT**
#
# $$ u \cdot v = \text{length of u projected onto v} = |u||v|cos\theta = u_1v_1+u_2v_2+u_3v_3+... $$
#
# **WEDGE/OUTER PRODUCT**
#
# $$ u \wedge v = -v \wedge u = \text{bivector made by u and v with direciton u} = |u||v|sin\theta = (u_1v_2 - u_2v_1)e_1e_2 + (u_2v_3 - u_3v_2)e_2e_3 + (u_3v_1 - u_1v_3)e_3e_1 $$
#
# That last term is for 3D only.
#
# We can also do this with arbitrary types of vectors and bivectors.
#
# **GEOMETRIC PRODUCT**
#
# $$ uv = u \cdot v + u \wedge v $$
#
# **EXPRESSING**
#
# $$ u\cdot v = \frac12 (uv + vu) $$
# $$ u\wedge v = \frac12 (uv - vu) $$
#
# We can find the geometric product of anything. Distribute and simplify!
#
# **PESUDOSCALARS**
#
# In 2D, $e_1e_2$ is reprsesented as i becasue it acts the same as the imaginary number. $e^{i\theta}$ works in 2 dimensions for rotations.
#
# The geometric product produces many things, but in 2D we can consider it a rotation operator with scaling by the magnitudes.
#
# PHYSICS APPLICATION: handles imaginary numbers and the complex plane.
#
# PHYSICS APPLICATION: Torque is a bivector.
#
# Anything labeled pseudovector and pseudoscalar are, in 3D at least, bivectors and trivectors.
#
# PHYSICS APPLICATION: relating bivectors on the left to trivectors and bevtors on the right define the pauli spin matrices. (With the spin matrices themselves acting as the unit vectors in disguise).
#
# PHYSICS APPLICATION: bivectors squared are negative one, we can map them to the quaternions.
#
# PHYSICS APPLICATION: three dimensional rotations! WITH A SANDWICH! $e^{- \frac12 \theta \hat I}ue^{\frac12 \theta \hat I}$. This is a rotor.
#
# PHYSICS APPLICATION: Rotors can be applied as a spinor.

# %% [markdown]
# Use multivectors for EM to arrive at:
#
# $$ \nabla = \frac1c \frac{\partial}{\partial t} + \frac{\partial}{\partial x} \hat x + \frac{\partial}{\partial y} \hat y + \frac{\partial}{\partial z} \hat z $$
#
# $$ J = c\rho - \vec J $$
#
# $$ F = \vec E + ic\vec B $$
#
# Note iB, as B is a cross product and logically should be a bivector, not a vector. And so Maxwell's Equations reduce to:
#
# $$ \nabla F = \frac{J}{c\epsilon_0} $$
#
# That's it. *THAT'S IT.* I repeat, there's nothing else, this is all there is, Maxwell's *Equation*.
#
# https://www.youtube.com/watch?v=0bOiy0HVMqA
#
# THE ADDENDUM let's see what it has...

# %% [markdown]
# Define a product between two vectors to be two parts: the perpendicular parts and the paralell parts.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# This paralellizing/perpendicularizing works in all senses visually.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What about when we extend to two bivectors? Well, two fully paralell bivectors multiply into a scalar, as all paralell segmetns cancel.
#
# ![image.png](attachment:image.png)
#
# When we have two bivectors that are paralell on one axis and not the other, the result is a bivector.
#
# Now in 3D you can always split things into arrangements like this, so to get the third case we need to rise to 4D, which reveals some weaknesses in our generalizations. Think of it this way:
#
# 2D: $(e_1e_2)(e_1e_2) = $scalar
#
# 3D: $(e_1e_2)(e_2e_3) = $bivector
#
# 4D: $(e_1e_2)(e_3e_4) = $4-vector. Quadvector?
#
# ![image-2.png](attachment:image-2.png)
#
# And this is why the form of the geometric product we used before is not fully general. It DOES apply up to 3D, but sometimes we need more. So we have the geometric product (r-vector)(s-vector) and get |r-s|-vector + |r-s|+2-vector +...etc all the way to (r+s)-vector.

# %% [markdown]
# Different Flavors can be done to get different spaces managed. Seems like it'd only really matter depending on what you wanted to do. The geometric algebra of lines use three components, one of them being for the scalar and squaring to 0. In this space the position of lines matters.
#
# https://www.youtube.com/watch?v=0i3ocLhbxJ4
#
# and now a discussion of OPERATIONS!
#
# In general:
#
# scalars: a number
#
# vectors: 1D suspace with orientation and magnitude.
#
# bivector: 2D subspace with orientation and magnitude.
#
# trivector: 3D subspace with orientation and magnitude.
#
# OPERATION: Grade Projection: $<A>_n$ produces the n-vector part (grade) of the multivector.
#
# To go further we need to define what space we are working in. G(p,q,r). The 3D space we have been using is G(3,0,0). Relativity has G(3,1,0) and linear geometric algebra has G(3,0,1) in 3D. The numbers are "how many basis vectors square to 1" "to -1" and "to 0". By defining how things square, and defining that unit vectors when swapped are anticommutative $e_1e_2 = -e_2e_1$, we then arrive at a sufficient definition of the geometric product.
#
# Maybe notation suggestion: $e_1e_2 = e_{12}$ potentially.
#
# REVERSE: $(uvw)^{\dagger} = (wvu)$.
#
# The reverse applies a sign flip every two grades 0 and 1 are positive, 2 and 3 are negative, then the 4-vector is positive again and so on.
#
# GRADE INVOLUTION: same as reverse but it flips the sign every other one, even grades are positive, odd are negative.
#
# MAGNITUDE: instead of squaring, multiply by its reverse. Which means $|A|^2 = A^\dagger A$. This should seem VERY FAMILIAR to what we do in quantum mechanics. Also if there are extra terms, truncate, so we really are finding $<A^\dagger A>_0$
#
# OUTER/WEDGE PRODUCT: $u \wedge v$. How do we calculate this? Often it's best to do wedge products in terms of unit vectors only, at which point it can be done a lot like a geometric product. Any time the unit vectors on either side of the wedge match it goes to zero for that term, and when they don't match well it's the standard geometric product. Whee!
#
# Another way to do it is just to do the geometric product and then take only the highest grade result. Theoretical contexts may have this best.
#
# REGRESSIVE PRODUCT: $u V v$. The "largest subspace contained in the inputs." We can write it as $A V B = (Ai \wedge Bi)i^{-1} $. Odd.
#
# INNER/DOT PRODUCT: Projection+Multiplication or Projection+Contraction. THis is usually intuitive, but when mixing grades it gets slightly funky. In general we can specify Left Contraction or Right Contraction which just tells us which one is projecting onto what. The issue is, if a larger order is being projected onto a smaleler order, we "give up" and say it's zero. Seems odd, but ultimately this is due to trying to assign a "negative grade," which doesn't exist, and it is sensible that it "vanishes" if you keep trying to shrink it. In general obviously dot the smaller onto the larger. Ignoring contractions, we can say:
#
# $$ a \cdot B = a_{||} B ; B \cdot a - B a_{||} $$
#
# Fun? Anyway, similarly we can use the geometric product, throw away perpendicular things, keep paralell.
#
# DUAL: Finds the orthogonal compliment. Normal algebras can just write this by Ai. However duality breaks when a basis vector squares to zero. * A is the dual. A * A = i works in most cases as well so it's... wow yeah this isn't intuitive is it. Geezums. It's also related to the Regressive product. Yeeeesh.
#
# An assistant for the products:
#
# The outer product of two basis multivectors is their geometric product if they share no factors.
#
# The inner product of two basis multivectors is their geometric product if they share all factors.
#
# $$ A_j \wedge B_k = <A_jB_k>_{j+k} $$
# $$ A_j \cdot B_k = <A_jB_k>_{|j-k|} $$
#
# For the *generality* of the objects.
#
# The contractions seem more useful in theoretical applications.

# %% [markdown]
# # BONUS
#
# ## Celestial Mechanics
#
# https://adsabs.harvard.edu/full/1983CeMec..30..151H
#
# Okay so turns out we kind of already did this and I didn't want to get into nuts and bolts.
