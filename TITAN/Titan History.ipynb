# %% [markdown]
# # Titan History
#
# ## From the first sight in the sky to the future of Dragonfly
#
# ### Surprisingly hard to find scholarly sources for historic information...

# %% [markdown]
# The history of Titan and humanity has been a strange one, but let's see just how weird it can get.
#
# It's somewhat annoying to find scholarly sources for all this information, but we have managed to find sufficient ones.
#
# ((Somehow managed to lose the first section of this document the first time around, yaaaay))

# %% [markdown]
# # Discovery

# %% [markdown]
# On March 25 1655, Christiaan Huygens discovered Titan, and he announced the discovery a year later [1]. At the moment of discovery, though, basically nothing was known about it; it was just a speck of light that could be observed to orbit Saturn. Huygens didn't even name it, simply calling it "Luna Saturni" which litearlly means "Saturn's Moon" [1]. That said, while Titan itself at this point was nothing more than a blip on the radar, the techniques used to discover it were state of the art at the time.
#
# Lenses prior to Huygens' time were made by hand, ground in a very laborious and difficult, and it was all but impossible to make large lenses precisely. Huygens and his brother invented a machine to do lens griding for them, and Huygens naturally put them immediately to use [1].
#
# There was a minor problem though: lens-based telescopes need to be really long to house the focal length of a lense, and larger lenses have larger focal lengths. The lens Huygens created had a focal length of 3.6 meters, and so in order to actually make use of it a traditional telescope would need to have a cylindrical casing around four meters long [1]! Creating such a long object would have been absurd, so Huygens just... didn't. The inner workings of the telescope were left exposed.
#
# ![image.png](attachment:image.png)
#
# *Image from [1], which itsel fi staken from the Royal Astronomical Society, which itself is an image taken of Smith, 1738: Compleat System of Optics*

# %% [markdown]
# The main lens was mounted on top of a large pole while Huygens looked through an eyepiece mounted on the ground. It certainly looks flimsy and prone to mishaps, but it was sufficient to see Titan. However, seeing a tiny moving speck of light does not automatically make it a moon. The piece of information that made Huygens sure was related to his other big contribution to astronomy--the deduction that the "apendages" around Saturn were, in fact, rings [1]. This new speck of light he had found happened to move in line with the rings, and so he deduced, correctly, that it was a moon. With that, Huygens cemented himself as Titan's discoverer.
#
# Astronomy is notorious for pre-discoveries--that is, observations of an object in before it's official discovery that did not identify what the object was. Both Christopher Wren and Johannes Hevelius claimed to have seen Titan before Huygens, but thought it was nothing more than a background star [1]. It's certainly possible this occured, but there aren't any records for us to investigate.
#
# After that, nothing happened for a while. More moons were discovered, but Titan itself was just a nameless speck. All we knew about it was where it was and roughly how long it took to orbit Saturn [1]. Naturally we could put some upper and lower bounds on its size, but nothing even remotely precise. It would take some time for techonlogy to advance to the point where distant observations would become viable.
#
# Before that, though, many other moons were found. They were originally identified only by number; not by discovery, but from innermost to outermost. This proved to be problematic when newer moons were discovered both further in and further out than other moons, and eventually John Herschel got fed up with it and gave the moons names based on mythology [1]. The moon we are concerned with, Titan, was named differently than the other moons of Saturn, which were named after titans and giants of mythology. The moon itself was named not after an individual, but the idea of a "titan" in general. This choice makes some sense, as Titan was clearly the most distinct of all the moons. Herschel himself even identified it as "the bright satellite" when he named it [2].

# %% [markdown]
# # Distant Observations

# %% [markdown]
# The next big piece of information about Titan came with the discovery of another moon, Hyperion, in 1848, over a century after the discovery of Titan [1]. The reason this was such a big deal is because it turns out that Titan and Hyperion are in orbital resonance, meaning their orbital periods are close enough to integer multiples of each other that their gravitational forces tug on each other in predictable patterns--patterns that can cause large changes over time. Speicically, they are in 3:4 resonance: for every 3 orbits Titan takes, Hyperion takes about 4. It's not exact, but this inexact nature is precisely what astronomers loved becuase it let them calculate Titan's mass based on how it was pulling Hyperion around [1]. The calculations were run in the 1880s. The mass estimate was around 20% off, which is amazing for astronomical estimations.
#
# Eventually, telescope technology started to get good enough that it could resolve Titan as more than a speck of light, but only just. Around this point the claims of dubious credibility start rolling in as people claim to see things they haven't--or perhaps have just tricked their eyes into seeing something that wasn't there. Such is the case with Jose Comas Sola who viewed Titan in 1907 and saw two bright circular patches on it, which we know aren't there. However, he *also* noted that the edge of Titan seemed darker than the interior, a phenomenon known as limb darkening that indicated a thick atmosphere's presence on the moon [1]. He was certainly right about this and scholars argue to this day whether it was even physically possible for him to have seen it, and if he did why he would have reported the bright patches as well.
#
# At this point we have a bit of historical mud in the way. By 1925 Sir James Jeans claimed in his book *Dynamical Theory of Gases* that an atmosphere around Titan had been discovered, and he applied his gas theory to Titan to show that it could have an atmosphere [1]. Jeans doesn't cite anyone so we don't know if he was refering to Sola (which seems likely) or something else. Regardless, at this point, the idea that Titan had an atmosphere was out there. Jeans showed that the gasses that made up the supposed atmosphere had to be heavy--no hydrogen or helium [1].
#
# Around this time observations became good enough to at least confirm that Titan was orange [3].
#
# Then came the breakthrough 1944 paper by Gerard Kuiper [3]. He proved definitively that Titan had an atmosphere not by examining limb darkening, but by a spectrum of Titan. When light strikes certain materials it behaves in certain particular ways at different wavelengths; some of it is scattered, some of it is absorbed, and some of it is transmitted. The culmination of all these effects is a spectral footprint. Some gasses have very strong footprints that are easy to see from very far away; such as methane, which Kuiper clearly identified when looking at Titan [3]. Thus, Titan had to have an atmosphere with a major constituent of gaseous methane.
#
# ![image.png](attachment:image.png)
#
# *Kuiper's spectrum. From [1], which itself is supposedly from [3] but the actual [3] itself has much blurrier images. Potentially this is due to printing and imaging differences.*
#
# There was no question: Titan had an atmosphere, making it a highly unusual object. But things were only about to get weirder... but first, we had to actually go there.

# %% [markdown]
# # Pioneer

# %% [markdown]
# The next good look at Titan came from the probe Pioneer 11 in 1979.
#
# ![Pntitan.jpg](attachment:Pntitan.jpg)
#
# *Titan as taken by Pioneer 11. https://commons.wikimedia.org/wiki/File:Pntitan.jpg*

# %% [markdown]
# # Voyager

# %% [markdown]
# # Cassini-Huygens

# %% [markdown]
# # The Future: Dragonfly

# %% [markdown]
# # Sources
#
# [1] **Lorenz and Mitton, 2002**: Lifting Titan's Veil: Exploring the Giant Moon of Saturn
#
# https://web.archive.org/web/20050222073209/https://assets.cambridge.org/052179/3483/sample/0521793483ws.pdf
#
# [2] **Herschel, 1847**: Astronomical Observations
#
# https://archive.org/details/Resultsastronom00Hers/page/414/mode/2up?view=theater&q=Titan
#
# [3] **Kuiper, 1944**: Titan: a Satellite With an Atmosphere
#
# https://articles.adsabs.harvard.edu/pdf/1944ApJ...100..378K
