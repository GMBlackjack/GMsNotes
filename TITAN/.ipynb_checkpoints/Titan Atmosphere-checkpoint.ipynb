# %% [markdown]
# # Titan's Atmosphere
#
# ## Always in the way
#
# ### But also arguably the most fascinating thing about the moon
#
# All right so you want to know about Titan's atmosphere. Well buckle up because it's a complicated mess even considering that we don't know all that much! As we can observe the atmosphere we certainly know more about it than, say, the surface, but that often just leads to more questions. It's extensive, it's big, and we totally don't know enough.
#
# This notebook is separated into major sections based on how close we're looking at the atmosphere. The first is **As A Whole**, where we look at the atmosphere as one object. Then we go into **Layers** which is normally how we look at Earth's atmosphere as well. However, Titan is not spherically symmetric in its atmosphere, so then we go to **Spatial Variations**. Then we look into **Localized Phenomena** such as clouds, storms, and other such weird things that are generally temporary. Tacked onto the end we have an **Origins** section on atmospheric formation theories and a **Methods** section describing how we do "science" with the atmosphere. (Both simulations and observations...?)
#
# In general it's a good idea to know this: the atmosphere is the thing we know the most about when it comes to Titan, as we can actually see it and get data about it directly. The problem is that it's also the thing preventing us from getting *other* data about Titan; namely the surface. Annoying but also fascinating.
#
# Organization is subject to change of course.
#
# For completneess sake: Titan's atmosphere was officially discovered in 1944 by Kuiper who notied the signature of methane in his sppectroscopic readings [2]. He also informed everyone the moon was orange. Good on him.
#
# ...Huh, guess searching "titan atmosphere" produces a very nice paper [1] in Google Scholar. Neat.

# %% [markdown]
# # As A Whole

# %% [markdown]
# Titan's atmosphere is extensive; its surface pressure is 1.5 bar [1]. Earth is 1 bar (well, if you don't care about hyper precision anyway), for the record. This fact that Titan's surface pressure is higher is even more remarkable when considering how small and weak Titan's gravity is coupled with the fact that both atmospheres are primarily nitrogen [1]. Earth and Titan's air is made out of the same primary constituent, and yet it's the smaller world with the higher pressure. Titan's atmosphere is also significantly more extensive, having scale heights of 15-50 km, opposed to Earth's 5-8 km [1].
#
# When we examine secondary constituents, things differ. Earth has oxygen; Titan has methane [1].
#
# The overall surface temperature of around 94 K is maintained by a greenhouse and antigreenhouse effect. The greenhouse effect is driven by methane (the obvious source) and collision-induced absorption (between various combinations of nitrogen, methane, and hydrogen molecules) [1]. The antigreenhouse effect comes from the haze layer [1 ?]. This temperature allows for methane to undergo a hydrological cycle akin to that of water, with storms, clouds, rain, and other such things occuring with methane instead of water. Roughly 80% of incoming light is absorbed by the atmosphere, and 10% by the surface [3].
#
# The upper atmosphere has some curious properties. The night side is warmer than the day side on average [1] and it's warmer overall when Titan is inside Saturn's magnetic field [1]. There are also very heavy ions up here, which is rather odd considering how hard it is to keep such things aloft [1] (though like many things on Titan we aren't exactly sure what these heavy ions are, merely that they are ions and are heavy. It's probably hydrocarbons though.). These large ions may be a hint as to how the haze is formed [1].
#
# Lots of other things have been found in the atmosphere: argon, ethane and other more complex hydrocarbons (in fact most of the things we find are hydrocarbons), hydrogen, hydrogen cyanide (and its isomer hydrogen isocyanide), a little water, carbonacious compounds, and a smattering of others [1]. Notable lack of oxygen, the only atoms seen are bound to carbon in carbon monoxide or carbon dioxide.
#
# Titan has a weird additional tilt. The axis of syjmmetry for the winds is tilted 4 degrees with respect to Titan's actual pole [1]. Freaky.
#
# Titan's atmosphere exhibits superrotation, like Venus [1]. Yes you can still have slow surface winds and have the atmosphere as a whole superrotate (i.e. the atmosphere spins faster than the planet).
#
# In short, as a whole Titan's atmosphere is rather simple: mostly nitrogen, some methane, other trace gasses, and a thick orange glop of smog that blocks everything. There usually aren't even many clouds, <1% of Titan's surface is covered at any given time [3]. It's the processes and finer details of the atmosphere that reveal its true complexity.
#
# So let us talk processes.

# %% [markdown]
# ## Large-Scale Chemistry
#
# Ah, atmospheric chemistry is so fun. You'd think with just nitrogen, methane, and a bunch of traces we'd be able to predict what happens. No. No we can't. We've identified what's in the atmosphere but not so much what it DOES. Fun stuff ahead.
#
# First of all, we have only detected molecules containing hydrogen, carbon, nitrogen, and oxygen in the atmosphere--well, and argon, but argon doesn't react with anything (usually) so we tend to ignore it. Obviously though there has to be other atom types since they could fall in from meteorites and the like [1], we just haven't detected them.
#
# Arguably the most important process for the atmosphere as a whole is the photonic dissociation of N2 and CH4 (methane) into their constituents. The chemical reactions that chain from this tend to result in the irreversible destruction of CH4 and formation of H2 [1]. This is a pretty well understood result, which brings us to a very prevalent question of why there is methane in Titan's atmosphere at all if it's supposed to be burned to a crisp already. It is known that the byproducts of this destruciton are what create the haze and Titan's orange-ness, but the specifics are elusive [1,2].
#
# During the day these processes are driven by sunlight, and during the night the job is taken over by Saturn's magnetic field though it is a lot less powerful [1].
#
# It seems like a good idea to go over the general process by which methane is destroyed. The photodissociation of N2 breaks it up into individual N molecules (which may or may not be ionic or excited, depending), and the same process turns CH4 into a variety of things: CH3, CH2, CH, H, and H2 depending on where things split off [1]. Yes you can also get ionic results as well here, the photon can break it apart in different ways depending on the energy. Now the hydrogen is very light and easily lost to space so it's not sticking around [1]. (I actually don't know if the hydrogen can even recombine with the organic remnants).
#
# A funny secondary reaction sequence occurs as well. Once C2H2 and C4H2 (acetylene, diacetylene) exist in the atmosphere, they can through a series of reactions "eat" the methane and only increase the rate at which it is destroyed by the normal photonic process [1]. In short, methane should be doomed as it is either broken up or smashed into heavier hydrocarbons. Yet it's still here. (Photons are still involved in this set of reacitons).
#
# Can any reactions produce more methane? Well, of all the products of the atmospheric chemistry, the most common (hydrogen) just floast away, five condense out of the atmosphere, and the others can dissociate but never into methane. (Bizarrely you can get C4H though, the opposite) [1]. So no.
#
# The models we have can replicate the small molecule abundances relatively easily, but larger molecules (which are important) elude us [1].
#
# While there is no (or very very very little) O2 present in Titan's atmosphere, there are a few oxygen-bearing species, CO and H2O. H2O is extremely unstable in Titan's atmosphere, while CO is extremely stable once formed [1]. These two molecules are rather mysterious--where is their source? (One may complain that Titan is mostly made up of H2O, but that's frozen, and not easily gotten into the atmosphere.) However, since oxygen *is* present, this means it's possible for "biotic" molecules to form.
#
# Note that some of these processes happen at different levels of the atmosphere that are subject to different kinds of radiation. We'll worry about the specifics later. N2 is sensitive to wavelengths below 100nm, CH4 is sensitive between 100nm and 145nm, and less energetic photons go deeper until a larger molecule stops them [1]. Keep in mind this is just for dissociation, as anyone who acutally tries to look at Titan knows, methane certainly absorbs in the infrared without a problem.
#
# ![image.png](attachment:image.png)
#
# *Potentially helpful diagram of the common byproducts in the atmosphere, naturally not including N2 and CH4. From [1].*

# %% [markdown]
# Of course methane doesn't block visible light. That would be the HAZE. The haze is everywhere. The haze is orange. The haze is our enemy. It's the most notable thing about the atmosphere at large scale and we've kind of been ignoring it up until now. The haze has multiple layers, at least one that is disjointed, and exists largely in the Stratosphere [1]. (Argue all you want about "but wait that should be discussed in layers," the haze is important to all layers, it just collects there). The particles in the haze are identified all the way from the surface to the ionosphere [1]. (Note: ionosphere/thermosphere appears to be used interchangeably a lot in this particular paper.)
#
# Examinations indicate that the haze particles are fractal "aggregates" of other particles [1] and properties that defy replication in attempted laboratory analogues (such as a mysterious 3.4 um feature and a lack of features at 3 and 4.6um. Admittedly these numbers seem random to me but I'm sure they really annoy some chemists) [1]. Clearly they're made up of hydrocarbons, though exactly which ones and how is unknown. C-H and C-C bonds dominate the spectrum. Which. Yeah it's a hydrocarbon of course that's what we're gonna find [1].
#
# Sometimes science just wants to screw with us. Almost everything we see implies that the haze is made mostly of hydrocarbons, that is, C and H. Meanwhile when Huygens flew through the haze and "cooked" it to see what there was, the products were HCN and NH3. This is unusual as there is notably *nitrogen* here, when that's not what hydrocarbons have in them [1]. Clearly we're missing something about these things.
#
# We do have some ideas about how these particles form. We may not know what the giant ions are, but we know they *exist*, and it's a natural assumption that these things are where the haze begins [1]. The exact path is a mystery, maybe it involves benzene, who knows? The ions form high up and then drift down where they settle into the haze. Most likely. Probably. It makes sense but the lack of specifics in knowledge is very annoying. What we can predict is that these mysteirous particles are more likely to be negative ions than positive, so they attract positive ions to themselves, growing in size--and then they can grow even further by the processes of nucleation and deposition and then even aggregation [1]. At this point more reactions can occur but the haze particles are already "gigantic" in molecular terms so this is a pain. Chemistry alone cannot explain the haze anymore, as now dynamic processes are in effect [1] which just adds to the calculation difficulty.
#
# The particles are fractal aggregates. [1] has a lot to say on this that I happen to know is wrong, there's another paper that specifies a fractional fractal dimension while [1] says "it's just 2."
#
# We spend a lot of effort trying to create materials that match the haze, and our attempts in laboratories are called "tholins" (though we sometimes call the material in the haze itself a "tholin") [1]. As was mentioned previously we have not yet succeeded in replicating the actual properties of the haze.
#
# In short: methane and nitrogen in atmosphere get zapped, making larger molecules because CHEMISTRY. Larger molecules start sinking and accumulating more particles as they sink. They eventually accumulate in the stratosphere due to "reasons" (and some of them probably fall to the ground). This accumulation layer is the orange haze of Titan. Tah-dah!

# %% [markdown]
# ## Seasons
#
# As Titan rotates relatively slowly, it has globaly Hadley circulation rather than cells like Earth [1]. Titan also has seasons due to its obliquity (26.7 degreesish), but these seasons are looooooooong as they move with Saturn's orbit, 29.5 years [3]. These seasons shift the overal direciton of Hadley circulation; during the seasons the airflow is from one pole to another, while during the shift there is temporarily two cells [1]. This curiously leads to a very small temperature differential across Titan, which makes one wonder why all the lakes are so fond of the poles... We are currently arguing over how high the Hadley circulation extends from the surface. The shift between summer and winter is evidentially short lived, as the "two cell" picture was only active in our observations for about six earth months [1]. This is a small amount of time for Titan.
#
# So yes all the stuff we just learned will change throughout the year based on seasonal winds and other nonsense that doesn't just sit still with time. And that's just globally, the poles do weird things in the seasons that we're not worrying about right now--but we will point out that the higher in the atmosphere you go, the more the seasons affect the temperature differential [1].

# %% [markdown]
# # Layers

# %% [markdown]
# A lot of planets in the solar system don't have well-defined atmosphere layers like Earth. Titan *does* have these well defined layers; a troposphere, a stratosphere, a mesosphere, and a thermosphere [1]. (And naturally an exosphere but those are always a little funky).
#
# ![388px-Titan's_atmosphere.svg.png](attachment:388px-Titan's_atmosphere.svg.png)
#
# *A diagram of Titan's atmospheric layers, from https://commons.wikimedia.org/wiki/File:Titan%27s_atmosphere.svg*

# %% [markdown]
# ## Troposphere
#
# From the ground to around 50km, the lowest atmospheric layer.
#
# Wind speeds are pretty low down here [1].
#
# Like on Earth this is where we get most of the weather, as the clouds tend to form here (when they can) [3]. The humidity in the Troposphere drives the global methane cycle [3]. Methane humidity is essentially 100% in this atmospheric layer from 8 to 40km, with lower values down to the ground.

# %% [markdown]
# ## Stratosphere
#
# This is where the haze collects.
#
# There's also a secondary ionosphere here since galactic cosmic rays cannot penetrate to Titan's surface, they stop here and start dissociating things [1].
#
# Anwyay, I mentioned the detached haze layer before. We can see it in pictures, it's pretty clear. The question is *why* and the answer is *we don't know yet* [1]. (There are smaller less noticable detached haze layers as well [1].) To put it simply, many theories have been suggested, none of them work, which means we probably have a combination situation. Every troubleshooter's worst nightmare: it's not *one* thing.
#
# The detached haze layer changes elevation too, apparently seasonally, just in case you didn't think it was weird enough [1]. It can even "vanish" or maybe just get too dim for us to see [1]. One suggestion is that the detached haze layer is where the flow of particles from above and the flow from below balance out--this is supported by the fact that the detached layer has particles in it that are too large to have formed higher in elevation [1].
#
# Presumaly the lower haze layer eventually drops compounds to the ground. At that point we know even less about the composition than we do when they're in the air.

# %% [markdown]
# ## Mesosphere

# %% [markdown]
# ## Thermosphere

# %% [markdown]
# Thermosphere temperatures are close to that of the Mesosphere on Titan due to efficient HCN cooling via "rotational lines" [1], despite the fact that there are in fact intense EUV heating rates here.

# %% [markdown]
# ## Exosphere

# %% [markdown]
# # Spatial Variations
#
# ## Y'know, not temporal
#
# ### Because seasons are kind of a higher-level effect overall and don't belong down here
#
# #### Of cousre some of these spatial variations are also temporally dependent but you don't need to know that. Oh wait.

# %% [markdown]
# The surface temperature gradient from the equator to the poles of Titan should be about 20K. However, the atmosphere conspires to move everythying around so that the actual temperature gradient is much smaller at 2-4K [3]. If something gets too hot on Titan it's getting moved elsewhere. This is why it is often said that Titan is "all tropics," as Earth's tropics do not vary in temperature much, and that applies to all of Titan [3]. (Or, well, most of it, naturally there are deviations as with almost all things).

# %% [markdown]
# So, while the global hadley circulation generally keeps the surface temperature in equilibriuum, this is not the case for other layers. The stratopause is warmer at the poles than the equator and it is the hottest part of the entire atmosphere [1], but this reverses at the lower stratosphere where the equatorial region is the warmer one.
#
# The winter hemisphere of Titan is darker at short wavelengths and brighter in near IR due to incresed haze opacity [1]. The winter pole also gains a polar hood, essentially a localized layer of haze on top of the other ones that only appears over the pole, theorized to be a result of downwelling at the witner pole [1].
#
# Methane transport does occur, overall it's evaporated from the equator and taken to the poles [3]. This is a tad unusual given how Titan usually has only one cell, but it is noted that the transport does occur from one pole to another as well. Overall the circulation is summer pole to winter pole [3].

# %% [markdown]
# # Localized Phenomena

# %% [markdown]
# ## Clouds
#
# ### Let's be honest this is *basically* the only localized atmospheric phenomena we're aware of.
#
# Clouds! Atmospheric phenomena! On Earth they are everywhere and impossible to avoid most of the time. On Titan if you look up you'd rarely see one. Also unlike earth we see lots of cloud *types*. Not types by shape, but types by what they're made of.
#
# There's you're bog-standard Titan methane cloud, of course, but there are also ethane clouds [1]. There's a bit of an "other" category called "high altitude cirrus clouds" that can be made of HCN, HC3N, etc. HCN itself can actually form some really massive couds, even if it's only temporariliy--we've seen one form inside a polar hood during winter and just remain there for a long time [1].
#
# We observe methane storms everywhere on Titan--it may be somewhat rare but it happens, even at the equator, despite theories thinking there's not enough methane "humidity" at the equator to do it [1].
#
# At the Huygens Landing Site, methane clouds form around 24 km in altitude, but they have been seen up to 40 km at higher latitudes [1]. You can tell this is a controversial measurement as another source, [3], has a 16km elevation polar cloud with 15-40 km mid-latitude clouds.
#
# Large storms do occur, but lightning is not observed [1]. These large storms can cover up to 10% of Titan's disc and occur every 3 to 18 months. Curiously, while we have detected the aftermath of rianfall, we have not detected any rain drops despite theoretically being able to [1].
#
# Methane clouds act and form rather similarly to Earth's clouds, lift it from the ground, condense, rain, repeat. However, the *other* clouds do not get to do this, as they come from *above* and condense that way [1]. The nitriles (organic compounds with nitrogen in them such as HCN) condesne at much higher altitudes than the hydrocarbons (ethane) [1]. Ethane clouds have been seen at the winter pole, as has the single known HCN cloud [1]. The ethane clouds were expected and predicted, but the HCN cloud was decidedly unusual *and* it formed at the same height as the detached haze layer [1]. Weird.
#
# Note that while methane clouds act similarly to Earth clouds, unlike water, methane is not "stuck" in the lower atmosphere and can propogate upward where the sun will annihilate it over time [1]. So while there is a "methane cycle" on Titan, if it operated in exactly the same way as our water cycle it would not be able to last forever. Which brings us back once again to the mystery of what exactly is maintaining the methane levels on Titan. I too would like an answer to this, mhm. The theories (there are many) all seem to demand some kind of methane resevoir in Titan that can release it to the atmosphere somehow [1].
#
# Also fun fact, sometimes we can't tell what the cloud is made of. Such was the case with the so-called "Haystack" feature [1]. Fun.

# %% [markdown]
# Equatorial and temparate clouds appear all the time, but polar clouds are more of a seasonal effect [3].

# %% [markdown]
# ## Vortexes
#
# ### And this is the thing that isn't a Cloud. I think.

# %% [markdown]
# # Origins

# %% [markdown]
# First question: Where did the nitrogen come from?
#
# Answer: it is either primordial, that is it was incorporated directly from the solar nebula, or it wasn't, in which case the primary suspect is NH3 (ammonia) which would then have to be photodissociated or chemically altered on the inside of Titan to produce the nitrogen gas [1]. One of the things Huygens did was constrain this: the ratio of 36Ar to 14N was orders of magnitude below the solar value, so it's unlikely that the nitrogen gas is primordial [1]. But that means we need to look at the *interior* of Titan for the origin of the atmosphere and, well, that's the least constrained part *of* Titan. We just don't know what's down there. Methane stores? Chemicals? Ammonia-water sea? Who knows, really.
#
# The next question would be "where did the methane come from" and honestly the answer is looking pretty similar: somewhere in the interior stuff be happening. What, exaclty, uh, who knows [1]. Again. The alternate hypothesis is that the methane in the atmosphere is very young. (There is a sort of hybrid theory mentioned, the periodic resupply, where methane is released into the atmosphere in huge bursts and then spends the next few million years slowly being annihilated.) NOTE: if we find tropical/teperate lakes, it will be very suggestive of subterranean methane resevoirs, which could supply the methane.
#
# The argon in the atmosphere doesn't need to be explained, it's a prevalent noble gas. We simply are able to use it to constrain the origins of other components.
#
# Which means up next we have... the oxygen. Where does it come from? The icy surface is not likely going to be a source of the stuff. However, unlike the msyterious subsurface processes for the nitrogen and methane, the oxygen actually has a pretty likely explanation: Enceladus has been shooting icy particles into space for who knows how long, creating one of Saturn's faint rings. The oxygen isotopes for Enceladus and Titan's atmosphere match, indicating they share an origin [1]. This is very suggestive that *Enceladus* is the source of the oxygen. Fascinating! (Most of this is in the form CO in modern times as H2O does not last long in Titan's atmosphere.) Sicne CO is so long-lived, it has likely accumulated over time, and thus primordial Titan probably had very little [1].
#
# This would leave just the hydrogen in the atmosphere. I don't think I need to point out that hydrogen, the most common element in the universe, is going to be literally everywhere without a problem. I don't even need to cite anything here for that! (And in addition, the specific source of atmospheric hydrogen is the photolysis of methane. The hydrogen then proceeds to escape rather quickly.)
#
# So, we have some origins: some stuff came from *somewhere* in the interior (N2, CH4), some stuff just coalesced naturally (Ar), some stuff comes from a cosmic source (CO, H2O), and some stuff is chemically produced (H2 and the rest of the minor constituents). So, that's "where" handled. Ish. The "how" leaves something to be desired in a few cases. But there is one question we haven't considered yet: "when?"
#
# Various measuring methods of this time can get you anywhere from less than 10 million years to the age of the solar system [1]. We're almost certain neither of these extremes are correct given the bounds given by multiple other methods but exactly how wrong is tough to tell. The compounding evidence is pretty strong that Titan's atmosphere as it is today has *not* existed for the majority of the age of the solar system. The majority of estimation methods coalesce around 300-500 million years ago [1]. Is this just a fluke or is it the age of the atmosphere? Who can say?
#
# ![image.png](attachment:image.png)
#
# *Various estimations of the age of Titan's atmosphere, from [1].*

# %% [markdown]
# Notably most of these restrictions are specifically methane restrictions. It is possible that the atmosphere was pure nitrogen prior to this, or that there are periodic methane outgassing events [1]. Curiously, if methane is not resupplied in a few tens of millions of years the methane will be gone and Titan will have a nearly pure nitrogen atmosphere, which would lower the surface temperature, make thin nitrogen clouds, and create a very dry surface [1].

# %% [markdown]
# # Methods

# %% [markdown]
# # References

# %% [markdown]
# [1] **Horst, 2017**: Titan's Atmosphere and Climate
#
# https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2016JE005240
#
# [2] **Kuiper, 1944**: Titan: a Satellite With an Atmosphere
#
# https://articles.adsabs.harvard.edu/pdf/1944ApJ...100..378K
#
# [3] **Mitchell and Lora, 2016**: The Climate of Titan
#
# https://www.annualreviews.org/doi/pdf/10.1146/annurev-earth-060115-012428
#
# [4] **Yung et al, 1984**: Photochemistry of the Atmosphere of Titan: Comparison Between Model and Obersvations
#
# https://articles.adsabs.harvard.edu/pdf/1984ApJS...55..465Y
